# %% [markdown]
# ## testa conexão

# %%
import json
import logging
from collections import Counter
import boto3
from resources.utils.utils import load_config, print_header


class IngestionValidation:
    config = load_config()
    _minio_endpoint_url = config["minio_dev"]["endpoint_url"]
    _minio_access_key = config["minio_dev"]["access_key"]
    _minio_secret_key = config["minio_dev"]["secret_key"]
    _storage_brew_bucket = config["storages"]["brew_bucket"]["name"]
    _storage_brew_landing = config["storages"]["brew_landing_key"]["lading"]
    
    _expected_schema = {
        "id": str,
        "name": str,
        "brewery_type": str,
        "address_1": (str, type(None)),
        "address_2": (str, type(None)),
        "address_3": (str, type(None)),
        "city": str,
        "state_province": str,
        "postal_code": str,
        "country": str,
        "longitude": (str, type(None)),
        "latitude": (str, type(None)),
        "phone": (str, type(None)),
        "website_url": (str, type(None)),
        "state": str,
        "street": (str, type(None))
    }



    def __init__(self):
        # Inicializa o cliente S3 (ou MinIO) com as credenciais e endpoint
        self.s3_client = boto3.client(
            's3',
            endpoint_url=self._minio_endpoint_url,
            aws_access_key_id=self._minio_access_key,
            aws_secret_access_key=self._minio_secret_key
        )

    def _list_files_in_bronze(self):
        """Lista todos os arquivos no bucket S3 na pasta bronze."""
        try:
            response = self.s3_client.list_objects_v2(
                Bucket=self._storage_brew_bucket,
                Prefix=self._storage_brew_landing
            )
            files = [content['Key'] for content in response.get('Contents', [])]
            # print("Arquivos encontrados:", files)
            return files
        except Exception as e:
            logging.error(f"Erro ao listar arquivos no bucket: {e}")
            return []

    def _read_s3_file(self, key):
        """Lê o conteúdo de um arquivo JSON do S3."""
        try:
            response = self.s3_client.get_object(Bucket=self._storage_brew_bucket, Key=key)
            content = response['Body'].read().decode('utf-8')
            return json.loads(content)
        except Exception as e:
            logging.error(f"Erro ao ler o arquivo {key}: {e}")
            return None


    def execute_test(self):
        msg = "INICIANDO VALIDAÇÃO DE CONEXÂO COM MINIO"
        print_header(msg)
        files = self._list_files_in_bronze()
        print(f"\nArquivos encontrados\n: {files}")
        for file in files:
            data = self._read_s3_file(file)
            print(f"\nArquivo {file} conteúdo")



if __name__ == "__main__":
    ingestion_validation = IngestionValidation()
    ingestion_validation.execute_test()
# Out:
# ************************************************************
# *                                                          *
# *     >>> INICIANDO VALIDAÇÃO DE CONEXÂO COM MINIO <<<     *
# *                                                          *
# ************************************************************
#
# Arquivos encontrados
# : ['bronze/PART_1_AT_2024_11_08.json', 'bronze/PART_2_AT_2024_11_08.json', 'bronze/PART_3_AT_2024_11_08.json', 'bronze/PART_4_AT_2024_11_08.json', 'bronze/PART_5_AT_2024_11_08.json', 'bronze/PART_6_AT_2024_11_08.json', 'bronze/PART_7_AT_2024_11_08.json', 'bronze/PART_8_AT_2024_11_08.json', 'bronze/PART_9_AT_2024_11_08.json']
#
# Arquivo bronze/PART_1_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_2_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_3_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_4_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_5_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_6_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_7_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_8_AT_2024_11_08.json conteúdo
#
# Arquivo bronze/PART_9_AT_2024_11_08.json conteúdo

# %% [markdown]
# ## Duck direto no minio

# %%
import duckdb
from resources.utils.utils import load_config, print_header

def create_duckdb_connection(
    minio_endpoint: str, minio_access_key: str, minio_secret_key: str
) -> duckdb.DuckDBPyConnection:
    """
    Estabelece uma conexão com o DuckDB e configura para usar as credenciais do MinIO.

    Esta função conecta ao DuckDB, instala e carrega as extensões HTTPFS e Delta, e cria um segredo S3 para configurar o
    acesso ao MinIO.

    Args:
        minio_endpoint (str): Endpoint do MinIO.
        minio_access_key (str): Chave de acesso do MinIO.
        minio_secret_key (str): Chave secreta do MinIO.

    Returns:
        duckdb.DuckDBPyConnection: Objeto de conexão do DuckDB se a conexão for bem-sucedida; caso contrário, None.

    Raises:
        Exception: Se houver um erro ao conectar ao DuckDB ou configurar o MinIO.
    """

    try:
        print("Conectando ao DuckDB")
        conn = duckdb.connect(database=':memory:')
        
        # Instala e carrega as extensões necessárias
        print("Instalando e carregando extensões HTTPFS e Delta")
        conn.execute("INSTALL httpfs;")
        conn.execute("LOAD httpfs;")
        conn.execute("INSTALL delta;")
        conn.execute("LOAD delta;")
        
        # Criação do segredo S3 para acessar o MinIO
        print("Criando e configurando o segredo S3")
        conn.execute(f"""
            CREATE SECRET delta_s3 (
                TYPE S3,
                KEY_ID '{minio_access_key}',  -- Chave de acesso do MinIO
                SECRET '{minio_secret_key}',  -- Chave secreta do MinIO
                REGION '',  -- Região vazia para MinIO
                ENDPOINT '{minio_endpoint}',  -- Endpoint do MinIO
                URL_STYLE 'path',  -- Acesso via estilo de caminho
                USE_SSL 'false'  -- Sem SSL para MinIO local
            );
        """)
        
        print("Conexão com DuckDB estabelecida e segredo configurado")
        return conn
    except Exception as e:
        print(f"Erro ao conectar ao DuckDB: {e}")
        return None


def load_silver_data(conn: duckdb.DuckDBPyConnection, silver_path: str):
    """
    Carrega os dados da camada Silver no DuckDB a partir do MinIO.

    Args:
        conn (duckdb.DuckDBPyConnection): Conexão DuckDB.
        silver_path (str): Caminho da camada Silver no MinIO.

    Returns:
        None
    """

    try:
        print(f"Tentando carregar dados do caminho {silver_path}...")
        conn.execute(f"CREATE TABLE silver_data AS SELECT * FROM delta_scan('{silver_path}')")
        print("Tabela 'silver_data' criada e dados carregados com sucesso.")
        
        # Consultas de exemplo
        total_records = conn.execute("SELECT COUNT(*) AS total_records FROM silver_data;").fetchdf()
        print("\nTotal de registros:", total_records)

        distinct_countries = conn.execute("SELECT DISTINCT country FROM silver_data;").fetchdf()
        print("\nPaíses distintos:", distinct_countries)

    except Exception as e:
        print(f"Erro ao carregar dados do MinIO com DuckDB: {e}")



config = load_config()

# Configurações do MinIO
minio_endpoint = config['minio_dev']['endpoint_url_duckdb']
minio_access_key = config['minio_dev']['access_key']
minio_secret_key = config["minio_dev"]["secret_key"]
minio_silver_path = config["storages"]["brew_paths_duckdb"]["silver"]

# Conectar ao DuckDB e carregar dados
conn = create_duckdb_connection(minio_endpoint, minio_access_key, minio_secret_key)
if conn:
    load_silver_data(conn, minio_silver_path)
    conn.close()
# Out:
# Conectando ao DuckDB
# Instalando e carregando extensões HTTPFS e Delta
# Criando e configurando o segredo S3
# Conexão com DuckDB estabelecida e segredo configurado
# Tentando carregar dados do caminho s3://lakehouse/silver/...
# Tabela 'silver_data' criada e dados carregados com sucesso.
#
# Total de registros:    total_records
# 0           8355
#
# Países distintos:           country
# 0          france
# 1         england
# 2          poland
# 3        portugal
# 4        scotland
# 5     south korea
# 6          sweden
# 7     isle of man
# 8   united states
# 9         austria
# 10      singapore
# 11        germany
# 12        ireland

# %%
import duckdb
from resources.utils.utils import load_config, print_header

class DuckDBMinIOConnector:
    def __init__(self):
        """
        Inicializa a conexão DuckDB com MinIO e carrega as configurações de conexão e caminhos.
        """
        # Carregar as configurações de MinIO e os caminhos do pipeline
        config = load_config()
        
        self.minio_endpoint = config['minio_dev']['endpoint_url_duckdb']
        self.minio_access_key = config['minio_dev']['access_key']
        self.minio_secret_key = config["minio_dev"]["secret_key"]
        self.brew_paths = config["storages"]["brew_paths_duckdb"]

        # Configurar a conexão
        self.conn = self._create_duckdb_connection()
    
    def _create_duckdb_connection(self) -> duckdb.DuckDBPyConnection:
        """
        Estabelece uma conexão com o DuckDB e configura o acesso ao MinIO.

        Returns:
            duckdb.DuckDBPyConnection: Objeto de conexão DuckDB.
        """
        try:
            print("Conectando ao DuckDB")
            conn = duckdb.connect(database=':memory:')
            
            # Instala e carrega as extensões necessárias
            print("Instalando e carregando extensões HTTPFS e Delta")
            conn.execute("INSTALL httpfs;")
            conn.execute("LOAD httpfs;")
            conn.execute("INSTALL delta;")
            conn.execute("LOAD delta;")
            
            # Criação do segredo S3 para acessar o MinIO
            print("Criando e configurando o segredo S3")
            conn.execute(f"""
                CREATE SECRET delta_s3 (
                    TYPE S3,
                    KEY_ID '{self.minio_access_key}',
                    SECRET '{self.minio_secret_key}',
                    REGION '',
                    ENDPOINT '{self.minio_endpoint}',
                    URL_STYLE 'path',
                    USE_SSL 'false'
                );
            """)
            
            print("Conexão com DuckDB estabelecida e segredo configurado")
            return conn
        except Exception as e:
            print(f"Erro ao conectar ao DuckDB: {e}")
            return None

    def execute_query(self, layer: str, query: str):
        """
        Executa uma consulta SQL na camada especificada (Bronze, Silver ou Gold).

        Args:
            layer (str): A camada dos dados (bronze, silver ou gold).
            query (str): A consulta SQL a ser executada.

        Returns:
            DataFrame: Resultado da consulta como DataFrame do DuckDB.
        """
        # Verifica o caminho da camada
        layer_path = self.brew_paths.get(layer)
        if not layer_path:
            print(f"Erro: Camada '{layer}' não encontrada nas configurações.")
            return None

        # Constrói a consulta para acessar os dados da camada específica
        try:
            print(f"Tentando carregar dados do caminho {layer_path} e executar a query...")
            self.conn.execute(f"CREATE TABLE {layer}_data AS SELECT * FROM delta_scan('{layer_path}')")
            result = self.conn.execute(query).fetchdf()
            print(f"Consulta executada com sucesso na camada {layer}.")
            return result
        except Exception as e:
            print(f"Erro ao carregar dados e executar consulta: {e}")
            return None
    
    def close_connection(self):
        """Fecha a conexão com o DuckDB."""
        if self.conn:
            self.conn.close()
            print("Conexão com o DuckDB fechada.")


# Exemplo de uso
connector = DuckDBMinIOConnector()
result = connector.execute_query("silver", "SELECT * FROM silver_data LIMIT 10;")
print(result)
connector.close_connection()
# Out:
# Conectando ao DuckDB
# Instalando e carregando extensões HTTPFS e Delta
# Criando e configurando o segredo S3
# Conexão com DuckDB estabelecida e segredo configurado
# Tentando carregar dados do caminho s3://lakehouse/silver/ e executar a query...
# Consulta executada com sucesso na camada silver.
#                                      id                              name  \
# 0  0a366f8e-fd0d-4fe6-8ee5-054d8b725c8c  Wieselburger Brauerei (Heineken)
# 1  3fe1de22-c30c-446d-b2f2-913ca9f6378e                        Wimitzbr�u
# 2  def4c1dd-dfdb-42ff-a03a-d2a00c9f3d7f        Zipfer Brauerei (Heineken)
# 3  f51b3f3d-be14-40da-914a-3b5c83f75bbf     Villacher Brauerei (Heineken)
# 4  867eee9e-2138-4e62-97a9-b25e7fd1a1ff  Klosterbrauerei Stift Engelszell
# 5  b04c9621-bb87-439d-a499-94cb432bde90                         Cafe Luis
# 6  9355bc7c-bdc7-40c3-8932-e840c996ed86                         Caf� Okei
# 7  16fb2c6e-c7e1-4d46-b9d0-1c86816eb129                 Die Bierbotschaft
# 8  fcd9312c-7531-4801-b481-52f4267cf628        Gösser Brauerei (Heineken)
# 9  56758247-521c-4219-afa2-0665c48c50ef    Puntigamer Brauerei (Heineken)
#
#   brewery_type            address_1 address_2 address_3               city  \
# 0        large      drbeurlestrae 1      None      None         wieselburg
# 1         nano                l67 7      None      None             wimitz
# 2        large              zipf 22      None      None               zipf
# 3        large      brauhausgasse 6      None      None            villach
# 4         nano         stiftstrae 6      None      None     engelhartszell
# 5          bar           weizberg 7      None      None               weiz
# 6          bar  feldkirchenstrae 40      None      None  kalsdorf bei graz
# 7      brewpub      ponigler str 52      None      None          wundschuh
# 8        large      brauhausgasse 1      None      None             leoben
# 9        large     triester str 361      None      None               graz
#
#   postal_code  country  longitude   latitude           phone  \
# 0        3250  austria  15.151875  48.137356     +4374165010
# 1        9311  austria  14.355971  46.839928    +43421228074
# 2        4871  austria  13.503958  48.036812     +4376823600
# 3        9500  austria  13.851683  46.616623   +434242277770
# 4        4090  austria  13.734607  48.498615     +4377178010
# 5        8160  austria  15.635828  47.223789     +4331723924
# 6        8401  austria  15.460421  46.971317    +43313557156
# 7        8142  austria  15.455187  46.912914   +436763530560
# 8        8700  austria  15.093344  47.362556   +438102069791
# 9        8055  austria  15.432570  47.029629  +4331629710013
#
#                                          website_url            state  \
# 0                         http://www.wieselburger.at  niedersterreich
# 1                         http://www.wimitzbraeu.com           krnten
# 2                              https://www.zipfer.at    obersterreich
# 3                          https://www.villacher.com           krnten
# 4  https://www.stift-engelszell.at/trappistenbrau...    obersterreich
# 5                                               None       steiermark
# 6                                    https://okei.at       steiermark
# 7                       https://www.bierbotschaft.at       steiermark
# 8                             https://www.goesser.at       steiermark
# 9                          https://www.puntigamer.at       steiermark
#
#                 street       last_updated_silver
# 0      drbeurlestrae 1 2024-11-08 08:03:31-03:00
# 1                l67 7 2024-11-08 08:03:31-03:00
# 2              zipf 22 2024-11-08 08:03:31-03:00
# 3      brauhausgasse 6 2024-11-08 08:03:31-03:00
# 4         stiftstrae 6 2024-11-08 08:03:31-03:00
# 5           weizberg 7 2024-11-08 08:03:31-03:00
# 6  feldkirchenstrae 40 2024-11-08 08:03:31-03:00
# 7      ponigler str 52 2024-11-08 08:03:31-03:00
# 8      brauhausgasse 1 2024-11-08 08:03:31-03:00
# 9     triester str 361 2024-11-08 08:03:31-03:00
# Conexão com o DuckDB fechada.

# %%
import duckdb
from resources.utils.utils import load_config

class DuckDBMinIOConnector:
    def __init__(self):
        """
        Inicializa a conexão DuckDB com MinIO e carrega as configurações de conexão e caminhos.
        """
        # Carregar as configurações de MinIO e os caminhos do pipeline
        config = load_config()
        
        self.minio_endpoint = config['minio_dev']['endpoint_url_duckdb']
        self.minio_access_key = config['minio_dev']['access_key']
        self.minio_secret_key = config["minio_dev"]["secret_key"]
        self.brew_paths = config["storages"]["brew_paths_duckdb"]

        # Configurar a conexão
        self.conn = self._create_duckdb_connection()
    
    def _create_duckdb_connection(self) -> duckdb.DuckDBPyConnection:
        """
        Estabelece uma conexão com o DuckDB e configura o acesso ao MinIO.

        Returns:
            duckdb.DuckDBPyConnection: Objeto de conexão DuckDB.
        """
        try:
            print("Conectando ao DuckDB")
            conn = duckdb.connect(database=':memory:')
            
            # Instala e carrega as extensões necessárias
            print("Instalando e carregando extensões HTTPFS e Delta")
            conn.execute("INSTALL httpfs;")
            conn.execute("LOAD httpfs;")
            conn.execute("INSTALL delta;")
            conn.execute("LOAD delta;")
            
            # Criação do segredo S3 para acessar o MinIO
            print("Criando e configurando o segredo S3")
            conn.execute(f"""
                CREATE SECRET delta_s3 (
                    TYPE S3,
                    KEY_ID '{self.minio_access_key}',
                    SECRET '{self.minio_secret_key}',
                    REGION '',
                    ENDPOINT '{self.minio_endpoint}',
                    URL_STYLE 'path',
                    USE_SSL 'false'
                );
            """)
            
            print("Conexão com DuckDB estabelecida e segredo configurado")
            return conn
        except Exception as e:
            print(f"Erro ao conectar ao DuckDB: {e}")
            return None

    def execute_query(self, layer: str, file_format: str, query: str):
        """
        Executa uma consulta SQL na camada especificada (Bronze, Silver ou Gold) com o formato de arquivo adequado.

        Args:
            layer (str): A camada dos dados (bronze, silver ou gold).
            file_format (str): O formato dos arquivos na camada ('json', 'delta', etc.).
            query (str): A consulta SQL a ser executada.

        Returns:
            DataFrame: Resultado da consulta como DataFrame do DuckDB.
        """
        # Verifica o caminho da camada
        layer_path = self.brew_paths.get(layer)
        if not layer_path:
            print(f"Erro: Camada '{layer}' não encontrada nas configurações.")
            return None

        # Constrói a consulta para acessar os dados com base no formato do arquivo
        try:
            print(f"Tentando carregar dados do caminho {layer_path} no formato {file_format} e executar a query...")
            if file_format.lower() == 'json':
                self.conn.execute(f"CREATE TABLE {layer}_data AS SELECT * FROM read_json_auto('{layer_path}*.json')")
            elif file_format.lower() == 'delta':
                self.conn.execute(f"CREATE TABLE {layer}_data AS SELECT * FROM delta_scan('{layer_path}')")
            else:
                print(f"Formato de arquivo '{file_format}' não suportado para a camada {layer}.")
                return None

            # Executa a query solicitada
            result = self.conn.execute(query).fetchdf()
            print(f"Consulta executada com sucesso na camada {layer}.")
            return result
        except Exception as e:
            print(f"Erro ao carregar dados e executar consulta: {e}")
            return None
    
    def close_connection(self):
        """Fecha a conexão com o DuckDB."""
        if self.conn:
            self.conn.close()
            print("Conexão com o DuckDB fechada.")


# Exemplo de uso
connector = DuckDBMinIOConnector()
result = connector.execute_query("silver", "delta", "SELECT * FROM bronze_data LIMIT 10;")
print(result)
connector.close_connection()
# Out:
# Conectando ao DuckDB
# Instalando e carregando extensões HTTPFS e Delta
# Criando e configurando o segredo S3
# Conexão com DuckDB estabelecida e segredo configurado
# Tentando carregar dados do caminho s3://lakehouse/silver/ no formato delta e executar a query...
# Erro ao carregar dados e executar consulta: Catalog Error: Table with name bronze_data does not exist!
# Did you mean "silver_data"?
# LINE 1: SELECT * FROM bronze_data LIMIT 10;
#                       ^
# None
# Conexão com o DuckDB fechada.

# %%
import duckdb
from resources.utils.utils import load_config

class DuckDBMinIOConnector:
    def __init__(self):
        """
        Inicializa a conexão DuckDB com MinIO e carrega as configurações de conexão e caminhos.
        """
        # Carregar as configurações de MinIO e os caminhos do pipeline
        config = load_config()
        
        self.minio_endpoint = config['minio_dev']['endpoint_url_duckdb']
        self.minio_access_key = config['minio_dev']['access_key']
        self.minio_secret_key = config["minio_dev"]["secret_key"]
        self.brew_paths = config["storages"]["brew_paths_duckdb"]

        # Configurar a conexão
        self.conn = self._create_duckdb_connection()
    
    def _create_duckdb_connection(self) -> duckdb.DuckDBPyConnection:
        """
        Estabelece uma conexão com o DuckDB e configura o acesso ao MinIO.

        Returns:
            duckdb.DuckDBPyConnection: Objeto de conexão DuckDB.
        """
        try:
            print("Conectando ao DuckDB")
            conn = duckdb.connect(database=':memory:')
            
            # Instala e carrega as extensões necessárias
            print("Instalando e carregando extensões HTTPFS e Delta")
            conn.execute("INSTALL httpfs;")
            conn.execute("LOAD httpfs;")
            conn.execute("INSTALL delta;")
            conn.execute("LOAD delta;")
            
            # Criação do segredo S3 para acessar o MinIO
            print("Criando e configurando o segredo S3")
            conn.execute(f"""
                CREATE SECRET delta_s3 (
                    TYPE S3,
                    KEY_ID '{self.minio_access_key}',
                    SECRET '{self.minio_secret_key}',
                    REGION '',
                    ENDPOINT '{self.minio_endpoint}',
                    URL_STYLE 'path',
                    USE_SSL 'false'
                );
            """)
            
            print("Conexão com DuckDB estabelecida e segredo configurado")
            return conn
        except Exception as e:
            print(f"Erro ao conectar ao DuckDB: {e}")
            return None

    def execute_query(self, layer: str, file_format: str, query: str):
        """
        Executa uma consulta SQL na camada especificada (Bronze, Silver ou Gold) com o formato de arquivo adequado.

        Args:
            layer (str): A camada dos dados (bronze, silver ou gold).
            file_format (str): O formato dos arquivos na camada ('json', 'delta', etc.).
            query (str): A consulta SQL a ser executada.

        Returns:
            DataFrame: Resultado da consulta como DataFrame do DuckDB.
        """
        # Verifica o caminho da camada
        layer_path = self.brew_paths.get(layer)
        if not layer_path:
            print(f"Erro: Camada '{layer}' não encontrada nas configurações.")
            return None

        # Define o nome da tabela a partir da camada
        table_name = f"{layer}_data"

        # Constrói a consulta para acessar os dados com base no formato do arquivo
        try:
            print(f"Tentando carregar dados do caminho {layer_path} no formato {file_format} e executar a query...")
            if file_format.lower() == 'json':
                self.conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM read_json_auto('{layer_path}*.json')")
            elif file_format.lower() == 'delta':
                self.conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM delta_scan('{layer_path}')")
            else:
                print(f"Formato de arquivo '{file_format}' não suportado para a camada {layer}.")
                return None

            # Substitui o nome da tabela correta na consulta
            query_with_table = query.replace("{{table}}", table_name)
            result = self.conn.execute(query_with_table).fetchdf()
            print(f"Consulta executada com sucesso na camada {layer}.")
            return result
        except Exception as e:
            print(f"Erro ao carregar dados e executar consulta: {e}")
            return None
    
    def close_connection(self):
        """Fecha a conexão com o DuckDB."""
        if self.conn:
            self.conn.close()
            print("Conexão com o DuckDB fechada.")


# Exemplo de uso

query= """
SELECT * FROM {{table}}
ORDER BY breweries_count desc
"""


connector = DuckDBMinIOConnector()
result = connector.execute_query("gold", "delta", query)
display_result(result)
connector.close_connection()
# Out:
# Conectando ao DuckDB
# Instalando e carregando extensões HTTPFS e Delta
# Criando e configurando o segredo S3
# Conexão com DuckDB estabelecida e segredo configurado
# Tentando carregar dados do caminho s3://lakehouse/gold/ no formato delta e executar a query...
# Consulta executada com sucesso na camada gold.
# +------+--------------+---------------+----------------------+----------------------------+-----------------+---------------------------+
# |      | brewery_type |    country    |        state         |            city            | breweries_count |     last_updated_gold     |
# +------+--------------+---------------+----------------------+----------------------------+-----------------+---------------------------+
# |  0   |    micro     | united states |       colorado       |           denver           |       58        | 2024-11-08 08:05:55-03:00 |
# |  1   |    micro     | united states |      california      |         san diego          |       45        | 2024-11-08 08:05:55-03:00 |
# |  2   |    micro     | united states |      washington      |          seattle           |       44        | 2024-11-08 08:05:55-03:00 |
# |  3   |    micro     | united states |        oregon        |          portland          |       41        | 2024-11-08 08:05:55-03:00 |
# |  4   |    micro     | united states |        texas         |           austin           |       30        | 2024-11-08 08:05:55-03:00 |
# |  5   |   brewpub    | united states |        oregon        |          portland          |       29        | 2024-11-08 08:05:55-03:00 |
# |  6   |    micro     | united states |       illinois       |          chicago           |       28        | 2024-11-08 08:05:55-03:00 |
# |  7   |     bar      |   singapore   |      singapore       |         singapore          |       28        | 2024-11-08 08:05:55-03:00 |
# |  8   |    micro     | united states |      minnesota       |        minneapolis         |       24        | 2024-11-08 08:05:55-03:00 |
# |  9   |    micro     | united states |        texas         |          houston           |       23        | 2024-11-08 08:05:55-03:00 |
# |  10  |   brewpub    | united states |      california      |         san diego          |       22        | 2024-11-08 08:05:55-03:00 |
# |  11  |   brewpub    | united states |       michigan       |        grand rapids        |       21        | 2024-11-08 08:05:55-03:00 |
# |  12  |    micro     | united states |      washington      |          spokane           |       20        | 2024-11-08 08:05:55-03:00 |
# |  13  |    micro     | united states |         ohio         |          columbus          |       19        | 2024-11-08 08:05:55-03:00 |
# |  14  |    micro     | united states |         ohio         |         cincinnati         |       18        | 2024-11-08 08:05:55-03:00 |
# |  15  |   brewpub    | united states |      washington      |          seattle           |       17        | 2024-11-08 08:05:55-03:00 |
# |  16  |    micro     | united states |       virginia       |          richmond          |       17        | 2024-11-08 08:05:55-03:00 |
# |  17  |    micro     | united states |       arizona        |           tucson           |       17        | 2024-11-08 08:05:55-03:00 |
# |  18  |    micro     | united states |    north carolina    |          raleigh           |       17        | 2024-11-08 08:05:55-03:00 |
# |  19  |   brewpub    | united states |       indiana        |        indianapolis        |       17        | 2024-11-08 08:05:55-03:00 |
# |  20  |   brewpub    | united states |      california      |       san francisco        |       17        | 2024-11-08 08:05:55-03:00 |
# |  21  |    micro     | united states |       colorado       |      colorado springs      |       17        | 2024-11-08 08:05:55-03:00 |
# |  22  |    micro     | united states |      new mexico      |        albuquerque         |       16        | 2024-11-08 08:05:55-03:00 |
# |  23  |    micro     | united states |    north carolina    |         charlotte          |       16        | 2024-11-08 08:05:55-03:00 |
# |  24  |   brewpub    | united states |       illinois       |          chicago           |       16        | 2024-11-08 08:05:55-03:00 |
# |  25  |    micro     | united states |      wisconsin       |         milwaukee          |       16        | 2024-11-08 08:05:55-03:00 |
# |  26  |   brewpub    | united states |         ohio         |         cleveland          |       15        | 2024-11-08 08:05:55-03:00 |
# |  27  |   brewpub    | united states |      new mexico      |        albuquerque         |       15        | 2024-11-08 08:05:55-03:00 |
# |  28  |    micro     | united states |      washington      |           tacoma           |       15        | 2024-11-08 08:05:55-03:00 |
# |  29  |    micro     | united states |      california      |       san francisco        |       15        | 2024-11-08 08:05:55-03:00 |
# |  30  |   brewpub    | united states |       colorado       |           denver           |       14        | 2024-11-08 08:05:55-03:00 |
# |  31  |    micro     | united states |       indiana        |        indianapolis        |       14        | 2024-11-08 08:05:55-03:00 |
# |  32  |    micro     | united states |      tennessee       |         nashville          |       14        | 2024-11-08 08:05:55-03:00 |
# |  33  |    micro     | united states |     pennsylvania     |         pittsburgh         |       14        | 2024-11-08 08:05:55-03:00 |
# |  34  |    micro     | united states |       kentucky       |         louisville         |       13        | 2024-11-08 08:05:55-03:00 |
# |  35  |    micro     | united states |      california      |        los angeles         |       13        | 2024-11-08 08:05:55-03:00 |
# |  36  |    micro     | united states |      minnesota       |         saint paul         |       13        | 2024-11-08 08:05:55-03:00 |
# |  37  |    micro     | united states |        maine         |          portland          |       13        | 2024-11-08 08:05:55-03:00 |
# |  38  |    micro     | united states |      california      |         sacramento         |       13        | 2024-11-08 08:05:55-03:00 |
# |  39  |    micro     | united states |       colorado       |        fort collins        |       13        | 2024-11-08 08:05:55-03:00 |
# |  40  |    micro     | united states |    north carolina    |         asheville          |       13        | 2024-11-08 08:05:55-03:00 |
# |  41  |    micro     | united states |       missouri       |        kansas city         |       12        | 2024-11-08 08:05:55-03:00 |
# |  42  |    micro     | united states |      california      |           vista            |       11        | 2024-11-08 08:05:55-03:00 |
# |  43  |    micro     | united states |       colorado       |          boulder           |       11        | 2024-11-08 08:05:55-03:00 |
# |  44  |    micro     | united states |         utah         |       salt lake city       |       11        | 2024-11-08 08:05:55-03:00 |
# |  45  |    micro     | united states |       oklahoma       |           tulsa            |       11        | 2024-11-08 08:05:55-03:00 |
# |  46  |    closed    | united states |      washington      |          seattle           |       11        | 2024-11-08 08:05:55-03:00 |
# |  47  |    micro     | united states |      washington      |         vancouver          |       11        | 2024-11-08 08:05:55-03:00 |
# |  48  |    micro     | united states |        idaho         |           boise            |       11        | 2024-11-08 08:05:55-03:00 |
# |  49  |   brewpub    | united states |     pennsylvania     |        philadelphia        |       11        | 2024-11-08 08:05:55-03:00 |
# |  50  |    micro     | united states |      california      |          oakland           |       10        | 2024-11-08 08:05:55-03:00 |
# |  51  |   planning   | united states |       colorado       |           denver           |       10        | 2024-11-08 08:05:55-03:00 |
# |  52  |    micro     | united states |        texas         |        san antonio         |       10        | 2024-11-08 08:05:55-03:00 |
# |  53  |    micro     | united states |    south carolina    |         charleston         |       10        | 2024-11-08 08:05:55-03:00 |
# |  54  |    micro     | united states |      california      |          torrance          |       10        | 2024-11-08 08:05:55-03:00 |
# |  55  |    micro     | united states |      california      |          anaheim           |       10        | 2024-11-08 08:05:55-03:00 |
# |  56  |   brewpub    | united states |    north carolina    |         asheville          |       10        | 2024-11-08 08:05:55-03:00 |
# |  57  |    micro     | united states |       florida        |      saint petersburg      |        9        | 2024-11-08 08:05:55-03:00 |
# |  58  |   brewpub    | united states |       colorado       |          boulder           |        9        | 2024-11-08 08:05:55-03:00 |
# |  59  |    micro     | united states |       florida        |           tampa            |        9        | 2024-11-08 08:05:55-03:00 |
# |  60  |   brewpub    | united states |       new york       |          buffalo           |        9        | 2024-11-08 08:05:55-03:00 |
# |  61  |    micro     | united states |       florida        |        jacksonville        |        9        | 2024-11-08 08:05:55-03:00 |
# |  62  |    micro     | united states |      washington      |         bellingham         |        9        | 2024-11-08 08:05:55-03:00 |
# |  63  |    micro     | united states |      washington      |           yakima           |        9        | 2024-11-08 08:05:55-03:00 |
# |  64  |    micro     | united states |      louisiana       |        new orleans         |        9        | 2024-11-08 08:05:55-03:00 |
# |  65  |    micro     | united states |       georgia        |          atlanta           |        9        | 2024-11-08 08:05:55-03:00 |
# |  66  |    micro     | united states |        nevada        |            reno            |        9        | 2024-11-08 08:05:55-03:00 |
# |  67  |    micro     | united states |       new york       |          brooklyn          |        9        | 2024-11-08 08:05:55-03:00 |
# |  68  |   brewpub    | united states |       colorado       |      colorado springs      |        9        | 2024-11-08 08:05:55-03:00 |
# |  69  |   brewpub    | united states |        texas         |           austin           |        9        | 2024-11-08 08:05:55-03:00 |
# |  70  |   brewpub    | united states |       missouri       |        saint louis         |        9        | 2024-11-08 08:05:55-03:00 |
# |  71  |    micro     | united states |    north carolina    |         wilmington         |        9        | 2024-11-08 08:05:55-03:00 |
# |  72  |    micro     | united states |        oregon        |            bend            |        9        | 2024-11-08 08:05:55-03:00 |
# |  73  |   planning   | united states |        texas         |          houston           |        9        | 2024-11-08 08:05:55-03:00 |
# |  74  |   brewpub    | united states |         ohio         |          columbus          |        9        | 2024-11-08 08:05:55-03:00 |
# |  75  |   brewpub    | united states |       michigan       |         ann arbor          |        8        | 2024-11-08 08:05:55-03:00 |
# |  76  |    micro     | united states |       florida        |           miami            |        8        | 2024-11-08 08:05:55-03:00 |
# |  77  |    micro     | united states |       michigan       |          holland           |        8        | 2024-11-08 08:05:55-03:00 |
# |  78  |    micro     | united states |        texas         |           dallas           |        8        | 2024-11-08 08:05:55-03:00 |
# |  79  |    micro     | united states |       kentucky       |         lexington          |        8        | 2024-11-08 08:05:55-03:00 |
# |  80  |    micro     | united states |       nebraska       |          lincoln           |        8        | 2024-11-08 08:05:55-03:00 |
# |  81  |    micro     | united states |       florida        |          orlando           |        8        | 2024-11-08 08:05:55-03:00 |
# |  82  |    micro     | united states |      washington      |        woodinville         |        8        | 2024-11-08 08:05:55-03:00 |
# |  83  |   brewpub    | united states |       georgia        |          atlanta           |        8        | 2024-11-08 08:05:55-03:00 |
# |  84  |   brewpub    | united states |       michigan       |         kalamazoo          |        8        | 2024-11-08 08:05:55-03:00 |
# |  85  |   brewpub    | united states |      minnesota       |        minneapolis         |        8        | 2024-11-08 08:05:55-03:00 |
# |  86  |    micro     | united states |         ohio         |         cleveland          |        8        | 2024-11-08 08:05:55-03:00 |
# |  87  |   brewpub    | united states |      tennessee       |         knoxville          |        8        | 2024-11-08 08:05:55-03:00 |
# |  88  |   contract   | united states |       new york       |          new york          |        8        | 2024-11-08 08:05:55-03:00 |
# |  89  |   brewpub    | united states |      wisconsin       |          madison           |        8        | 2024-11-08 08:05:55-03:00 |
# |  90  |   brewpub    | united states |         ohio         |         cincinnati         |        8        | 2024-11-08 08:05:55-03:00 |
# |  91  |    micro     | united states |      tennessee       |         knoxville          |        8        | 2024-11-08 08:05:55-03:00 |
# |  92  |   brewpub    | united states |         utah         |       salt lake city       |        8        | 2024-11-08 08:05:55-03:00 |
# |  93  |    micro     | united states |     pennsylvania     |        philadelphia        |        8        | 2024-11-08 08:05:55-03:00 |
# |  94  |   brewpub    | united states |      washington      |         vancouver          |        7        | 2024-11-08 08:05:55-03:00 |
# |  95  |    micro     | united states |       colorado       |          greeley           |        7        | 2024-11-08 08:05:55-03:00 |
# |  96  |    micro     | united states |       colorado       |         littleton          |        7        | 2024-11-08 08:05:55-03:00 |
# |  97  |    micro     | united states |      tennessee       |          memphis           |        7        | 2024-11-08 08:05:55-03:00 |
# |  98  |    closed    | united states |      washington      |          spokane           |        7        | 2024-11-08 08:05:55-03:00 |
# |  99  |   brewpub    | united states |        nevada        |            reno            |        7        | 2024-11-08 08:05:55-03:00 |
# | 100  |    micro     | united states |      california      |          san jose          |        7        | 2024-11-08 08:05:55-03:00 |
# | 101  |    micro     | united states |        oregon        |           eugene           |        7        | 2024-11-08 08:05:55-03:00 |
# | 102  |   brewpub    | united states |       nebraska       |           omaha            |        7        | 2024-11-08 08:05:55-03:00 |
# | 103  |    micro     | united states |       oklahoma       |       oklahoma city        |        7        | 2024-11-08 08:05:55-03:00 |
# | 104  |    micro     | united states |       colorado       |          loveland          |        7        | 2024-11-08 08:05:55-03:00 |
# | 105  |    micro     | united states |       virginia       |       virginia beach       |        7        | 2024-11-08 08:05:55-03:00 |
# | 106  |   brewpub    | united states |       maryland       |         baltimore          |        7        | 2024-11-08 08:05:55-03:00 |
# | 107  |    micro     | united states |       new york       |         rochester          |        7        | 2024-11-08 08:05:55-03:00 |
# | 108  |   brewpub    | united states |    north carolina    |         charlotte          |        7        | 2024-11-08 08:05:55-03:00 |
# | 109  |    closed    | united states |      california      |         san diego          |        7        | 2024-11-08 08:05:55-03:00 |
# | 110  |    micro     | united states |       missouri       |        saint louis         |        7        | 2024-11-08 08:05:55-03:00 |
# | 111  |   brewpub    | united states |       arizona        |          phoenix           |        7        | 2024-11-08 08:05:55-03:00 |
# | 112  |    micro     |    ireland    |        dublin        |           dublin           |        7        | 2024-11-08 08:05:55-03:00 |
# | 113  |    micro     | united states |       michigan       |       traverse city        |        7        | 2024-11-08 08:05:55-03:00 |
# | 114  |   brewpub    | united states |      california      |        los angeles         |        6        | 2024-11-08 08:05:55-03:00 |
# | 115  |   brewpub    | united states |        kansas        |          wichita           |        6        | 2024-11-08 08:05:55-03:00 |
# | 116  |    micro     | united states |       florida        |         fort myers         |        6        | 2024-11-08 08:05:55-03:00 |
# | 117  |    micro     | united states |       virginia       |      charlottesville       |        6        | 2024-11-08 08:05:55-03:00 |
# | 118  |    micro     | united states |       new york       |          buffalo           |        6        | 2024-11-08 08:05:55-03:00 |
# | 119  |    micro     | united states |       virginia       |          norfolk           |        6        | 2024-11-08 08:05:55-03:00 |
# | 120  |    micro     | united states |        alaska        |         anchorage          |        6        | 2024-11-08 08:05:55-03:00 |
# | 121  |   brewpub    | united states |       missouri       |        kansas city         |        6        | 2024-11-08 08:05:55-03:00 |
# | 122  |    micro     | united states |       arizona        |         flagstaff          |        6        | 2024-11-08 08:05:55-03:00 |
# | 123  |    micro     | united states |      california      |          ventura           |        6        | 2024-11-08 08:05:55-03:00 |
# | 124  |    micro     | united states |       wyoming        |           casper           |        6        | 2024-11-08 08:05:55-03:00 |
# | 125  |   brewpub    | united states |      california      |         santa rosa         |        6        | 2024-11-08 08:05:55-03:00 |
# | 126  |    micro     | united states |       virginia       |          manassas          |        6        | 2024-11-08 08:05:55-03:00 |
# | 127  |    micro     | united states |       illinois       |       saint charles        |        6        | 2024-11-08 08:05:55-03:00 |
# | 128  |   brewpub    | united states |        oregon        |            bend            |        6        | 2024-11-08 08:05:55-03:00 |
# | 129  |    large     | united states |      california      |         san diego          |        6        | 2024-11-08 08:05:55-03:00 |
# | 130  |    micro     | united states |       missouri       |        springfield         |        6        | 2024-11-08 08:05:55-03:00 |
# | 131  |   planning   | united states |       new york       |          brooklyn          |        6        | 2024-11-08 08:05:55-03:00 |
# | 132  |   planning   | united states |       illinois       |          chicago           |        6        | 2024-11-08 08:05:55-03:00 |
# | 133  |   contract   | united states |       illinois       |          chicago           |        6        | 2024-11-08 08:05:55-03:00 |
# | 134  |   brewpub    | united states | district of columbia |         washington         |        6        | 2024-11-08 08:05:55-03:00 |
# | 135  |   planning   | united states |       arizona        |          phoenix           |        6        | 2024-11-08 08:05:55-03:00 |
# | 136  |   planning   | united states |        texas         |           austin           |        6        | 2024-11-08 08:05:55-03:00 |
# | 137  |    micro     | united states |       colorado       |          longmont          |        6        | 2024-11-08 08:05:55-03:00 |
# | 138  |   brewpub    | united states |     pennsylvania     |         pittsburgh         |        6        | 2024-11-08 08:05:55-03:00 |
# | 139  |   brewpub    | united states |        texas         |        san antonio         |        6        | 2024-11-08 08:05:55-03:00 |
# | 140  |   brewpub    | united states |      new mexico      |          santa fe          |        6        | 2024-11-08 08:05:55-03:00 |
# | 141  |    micro     | united states |       new york       |      long island city      |        6        | 2024-11-08 08:05:55-03:00 |
# | 142  |   brewpub    | united states |        alaska        |         anchorage          |        6        | 2024-11-08 08:05:55-03:00 |
# | 143  |    micro     | united states |       maryland       |         baltimore          |        6        | 2024-11-08 08:05:55-03:00 |
# | 144  |   brewpub    | united states |     south dakota     |        sioux falls         |        6        | 2024-11-08 08:05:55-03:00 |
# | 145  |    micro     | united states |       alabama        |         birmingham         |        6        | 2024-11-08 08:05:55-03:00 |
# | 146  |   brewpub    | united states |        hawaii        |          honolulu          |        6        | 2024-11-08 08:05:55-03:00 |
# | 147  |    micro     | united states |         ohio         |           akron            |        6        | 2024-11-08 08:05:55-03:00 |
# | 148  |    micro     | united states |      california      |         santa rosa         |        6        | 2024-11-08 08:05:55-03:00 |
# | 149  |   brewpub    | united states |       florida        |           tampa            |        6        | 2024-11-08 08:05:55-03:00 |
# | 150  |   brewpub    | united states |       colorado       |        fort collins        |        6        | 2024-11-08 08:05:55-03:00 |
# | 151  |   brewpub    | united states |        texas         |           dallas           |        6        | 2024-11-08 08:05:55-03:00 |
# | 152  |    micro     | united states |    south carolina    |      north charleston      |        6        | 2024-11-08 08:05:55-03:00 |
# | 153  |    micro     | united states |      california      |         oceanside          |        6        | 2024-11-08 08:05:55-03:00 |
# | 154  |   brewpub    | united states |       new york       |          brooklyn          |        6        | 2024-11-08 08:05:55-03:00 |
# | 155  |    micro     | united states |       colorado       |           aurora           |        6        | 2024-11-08 08:05:55-03:00 |
# | 156  |    micro     | united states |       montana        |          bozeman           |        6        | 2024-11-08 08:05:55-03:00 |
# | 157  |   planning   | united states |       florida        |           miami            |        6        | 2024-11-08 08:05:55-03:00 |
# | 158  |    micro     | united states |     south dakota     |         rapid city         |        6        | 2024-11-08 08:05:55-03:00 |
# | 159  |    micro     | united states |       colorado       |         centennial         |        5        | 2024-11-08 08:05:55-03:00 |
# | 160  |    micro     | united states |      wisconsin       |          madison           |        5        | 2024-11-08 08:05:55-03:00 |
# | 161  |    micro     | united states |       virginia       |          leesburg          |        5        | 2024-11-08 08:05:55-03:00 |
# | 162  |   regional   | united states |      california      |         san diego          |        5        | 2024-11-08 08:05:55-03:00 |
# | 163  |    micro     | united states |       alabama        |         huntsville         |        5        | 2024-11-08 08:05:55-03:00 |
# | 164  |    micro     | united states |        oregon        |          roseburg          |        5        | 2024-11-08 08:05:55-03:00 |
# | 165  |    micro     | united states |    north carolina    |          concord           |        5        | 2024-11-08 08:05:55-03:00 |
# | 166  |   brewpub    | united states |        idaho         |           boise            |        5        | 2024-11-08 08:05:55-03:00 |
# | 167  |    micro     | united states |        kansas        |          wichita           |        5        | 2024-11-08 08:05:55-03:00 |
# | 168  |   brewpub    | united states |        oregon        |           eugene           |        5        | 2024-11-08 08:05:55-03:00 |
# | 169  |    micro     | united states |        oregon        |          redmond           |        5        | 2024-11-08 08:05:55-03:00 |
# | 170  |    micro     | united states |    north carolina    |         greensboro         |        5        | 2024-11-08 08:05:55-03:00 |
# | 171  |   brewpub    | united states |      california      |            napa            |        5        | 2024-11-08 08:05:55-03:00 |
# | 172  |   brewpub    | united states |        texas         |          houston           |        5        | 2024-11-08 08:05:55-03:00 |
# | 173  |    micro     | united states |       florida        |         clearwater         |        5        | 2024-11-08 08:05:55-03:00 |
# | 174  |   brewpub    | united states |      washington      |          richland          |        5        | 2024-11-08 08:05:55-03:00 |
# | 175  |   brewpub    | united states |      california      |      san luis obispo       |        5        | 2024-11-08 08:05:55-03:00 |
# | 176  |   brewpub    | united states |        nevada        |         las vegas          |        5        | 2024-11-08 08:05:55-03:00 |
# | 177  |    micro     | united states |     south dakota     |        sioux falls         |        5        | 2024-11-08 08:05:55-03:00 |
# | 178  |    micro     | united states |        idaho         |        garden city         |        5        | 2024-11-08 08:05:55-03:00 |
# | 179  |   brewpub    | united states |       colorado       |          durango           |        5        | 2024-11-08 08:05:55-03:00 |
# | 180  |   regional   | united states |         ohio         |         cincinnati         |        5        | 2024-11-08 08:05:55-03:00 |
# | 181  |   planning   | united states |    north carolina    |         charlotte          |        5        | 2024-11-08 08:05:55-03:00 |
# | 182  |    micro     | united states | district of columbia |         washington         |        5        | 2024-11-08 08:05:55-03:00 |
# | 183  |   brewpub    | united states |    massachusetts     |           boston           |        5        | 2024-11-08 08:05:55-03:00 |
# | 184  |   brewpub    | united states |    north carolina    |         wilmington         |        5        | 2024-11-08 08:05:55-03:00 |
# | 185  |    micro     | united states |       florida        |        tallahassee         |        5        | 2024-11-08 08:05:55-03:00 |
# | 186  |   brewpub    | united states |       michigan       |          detroit           |        5        | 2024-11-08 08:05:55-03:00 |
# | 187  |    micro     | united states |      washington      |         snohomish          |        5        | 2024-11-08 08:05:55-03:00 |
# | 188  |    micro     | united states |      california      |          carlsbad          |        5        | 2024-11-08 08:05:55-03:00 |
# | 189  |   brewpub    | united states |       arizona        |         scottsdale         |        5        | 2024-11-08 08:05:55-03:00 |
# | 190  |    micro     | united states |        texas         |         fort worth         |        5        | 2024-11-08 08:05:55-03:00 |
# | 191  |    micro     | united states |       virginia       |       fredericksburg       |        5        | 2024-11-08 08:05:55-03:00 |
# | 192  |    micro     |    england    |     east sussex      |          brighton          |        5        | 2024-11-08 08:05:55-03:00 |
# | 193  |    micro     | united states |         iowa         |         des moines         |        5        | 2024-11-08 08:05:55-03:00 |
# | 194  |    micro     | united states |       florida        |        gainesville         |        5        | 2024-11-08 08:05:55-03:00 |
# | 195  |    micro     | united states |       indiana        |         fort wayne         |        5        | 2024-11-08 08:05:55-03:00 |
# | 196  |   brewpub    | united states |       virginia       |          richmond          |        5        | 2024-11-08 08:05:55-03:00 |
# | 197  |    micro     | united states |       montana        |          missoula          |        5        | 2024-11-08 08:05:55-03:00 |
# | 198  |   brewpub    | united states |      california      |         sacramento         |        5        | 2024-11-08 08:05:55-03:00 |
# | 199  |   brewpub    | united states |      california      |         santa cruz         |        5        | 2024-11-08 08:05:55-03:00 |
# | 200  |    micro     | united states |      california      |         san marcos         |        5        | 2024-11-08 08:05:55-03:00 |
# | 201  |    micro     | united states |       new york       |         riverhead          |        5        | 2024-11-08 08:05:55-03:00 |
# | 202  |    micro     | united states |      tennessee       |        chattanooga         |        5        | 2024-11-08 08:05:55-03:00 |
# | 203  |    micro     | united states |        oregon        |           salem            |        5        | 2024-11-08 08:05:55-03:00 |
# | 204  |   brewpub    | united states |       arkansas       |        little rock         |        5        | 2024-11-08 08:05:55-03:00 |
# | 205  |    micro     | united states |       montana        |           helena           |        5        | 2024-11-08 08:05:55-03:00 |
# | 206  |    micro     | united states |      washington      |         bremerton          |        5        | 2024-11-08 08:05:55-03:00 |
# | 207  |    micro     | united states |       maryland       |         frederick          |        5        | 2024-11-08 08:05:55-03:00 |
# | 208  |    micro     | united states |       virginia       |        williamsburg        |        5        | 2024-11-08 08:05:55-03:00 |
# | 209  |    micro     | united states |       new york       |          syracuse          |        5        | 2024-11-08 08:05:55-03:00 |
# | 210  |    micro     | united states |       florida        |          dunedin           |        5        | 2024-11-08 08:05:55-03:00 |
# | 211  |   brewpub    | united states |       arkansas       |        fayetteville        |        5        | 2024-11-08 08:05:55-03:00 |
# | 212  |    micro     | united states |       nebraska       |           omaha            |        5        | 2024-11-08 08:05:55-03:00 |
# | 213  |   planning   | united states |      california      |         san diego          |        5        | 2024-11-08 08:05:55-03:00 |
# | 214  |    micro     | united states |       michigan       |         kalamazoo          |        5        | 2024-11-08 08:05:55-03:00 |
# | 215  |   brewpub    | united states |       new york       |         rochester          |        5        | 2024-11-08 08:05:55-03:00 |
# | 216  |   brewpub    | united states |       michigan       |       traverse city        |        5        | 2024-11-08 08:05:55-03:00 |
# | 217  |   brewpub    | united states |       kentucky       |         louisville         |        5        | 2024-11-08 08:05:55-03:00 |
# | 218  |    micro     | united states |      washington      |       spokane valley       |        5        | 2024-11-08 08:05:55-03:00 |
# | 219  |    micro     | united states |      california      |      rancho cucamonga      |        5        | 2024-11-08 08:05:55-03:00 |
# | 220  |   brewpub    | united states |        oregon        |         corvallis          |        5        | 2024-11-08 08:05:55-03:00 |
# | 221  |    micro     | united states |        nevada        |         henderson          |        5        | 2024-11-08 08:05:55-03:00 |
# | 222  |   regional   | united states |       missouri       |        saint louis         |        5        | 2024-11-08 08:05:55-03:00 |
# | 223  |    micro     | united states |       arkansas       |        little rock         |        5        | 2024-11-08 08:05:55-03:00 |
# | 224  |     bar      |    germany    |        berlin        |           berlin           |        5        | 2024-11-08 08:05:55-03:00 |
# | 225  |    micro     |    sweden     |       blekinge       |         karlskrona         |        4        | 2024-11-08 08:05:55-03:00 |
# | 226  |   brewpub    |    poland     |      dolnolskie      |           wrocaw           |        4        | 2024-11-08 08:05:55-03:00 |
# | 227  |   brewpub    | united states |        oregon        |           salem            |        4        | 2024-11-08 08:05:55-03:00 |
# | 228  |    micro     | united states |     north dakota     |           fargo            |        4        | 2024-11-08 08:05:55-03:00 |
# | 229  |    micro     | united states |    new hampshire     |         portsmouth         |        4        | 2024-11-08 08:05:55-03:00 |
# | 230  |    micro     | united states |       new york       |         bay shore          |        4        | 2024-11-08 08:05:55-03:00 |
# | 231  |   brewpub    | united states |     pennsylvania     |         harrisburg         |        4        | 2024-11-08 08:05:55-03:00 |
# | 232  |    micro     | united states |        nevada        |         las vegas          |        4        | 2024-11-08 08:05:55-03:00 |
# | 233  |   brewpub    | united states |       colorado       |        castle rock         |        4        | 2024-11-08 08:05:55-03:00 |
# | 234  |    micro     | united states |        texas         |      dripping springs      |        4        | 2024-11-08 08:05:55-03:00 |
# | 235  |    micro     | united states |      california      |      westlake village      |        4        | 2024-11-08 08:05:55-03:00 |
# | 236  |    micro     | united states |       new york       |          holbrook          |        4        | 2024-11-08 08:05:55-03:00 |
# | 237  |   brewpub    | united states |         iowa         |        cedar rapids        |        4        | 2024-11-08 08:05:55-03:00 |
# | 238  |    micro     | united states |       georgia        |          savannah          |        4        | 2024-11-08 08:05:55-03:00 |
# | 239  |   brewpub    | united states |         ohio         |           dayton           |        4        | 2024-11-08 08:05:55-03:00 |
# | 240  |    micro     | united states |    massachusetts     |        easthampton         |        4        | 2024-11-08 08:05:55-03:00 |
# | 241  |    micro     | united states |    north carolina    |           durham           |        4        | 2024-11-08 08:05:55-03:00 |
# | 242  |    closed    | united states |      wisconsin       |         milwaukee          |        4        | 2024-11-08 08:05:55-03:00 |
# | 243  |    micro     | united states |       colorado       |         lafayette          |        4        | 2024-11-08 08:05:55-03:00 |
# | 244  |   planning   | united states |        texas         |           dallas           |        4        | 2024-11-08 08:05:55-03:00 |
# | 245  |   brewpub    | united states |       new york       |          syracuse          |        4        | 2024-11-08 08:05:55-03:00 |
# | 246  |    micro     | united states |        texas         |       new braunfels        |        4        | 2024-11-08 08:05:55-03:00 |
# | 247  |    micro     | united states |       arkansas       |           rogers           |        4        | 2024-11-08 08:05:55-03:00 |
# | 248  |    micro     | united states |       florida        |          sarasota          |        4        | 2024-11-08 08:05:55-03:00 |
# | 249  |   brewpub    | united states |      minnesota       |           duluth           |        4        | 2024-11-08 08:05:55-03:00 |
# | 250  |    micro     | united states |       florida        |         bradenton          |        4        | 2024-11-08 08:05:55-03:00 |
# | 251  |    micro     | united states |       virginia       |        purcellville        |        4        | 2024-11-08 08:05:55-03:00 |
# | 252  |   brewpub    | united states |       florida        |          orlando           |        4        | 2024-11-08 08:05:55-03:00 |
# | 253  |    micro     | united states |      california      |       rancho cordova       |        4        | 2024-11-08 08:05:55-03:00 |
# | 254  |    micro     | united states |    massachusetts     |          plymouth          |        4        | 2024-11-08 08:05:55-03:00 |
# | 255  |    micro     | united states |       montana        |          billings          |        4        | 2024-11-08 08:05:55-03:00 |
# | 256  |    micro     | united states |       florida        |      saint augustine       |        4        | 2024-11-08 08:05:55-03:00 |
# | 257  |    micro     | united states |       vermont        |         burlington         |        4        | 2024-11-08 08:05:55-03:00 |
# | 258  |    micro     | united states |       florida        |         pensacola          |        4        | 2024-11-08 08:05:55-03:00 |
# | 259  |    micro     | united states |       florida        |       pompano beach        |        4        | 2024-11-08 08:05:55-03:00 |
# | 260  |    closed    | united states |      washington      |         bellingham         |        4        | 2024-11-08 08:05:55-03:00 |
# | 261  |   brewpub    | united states |      california      |          oakland           |        4        | 2024-11-08 08:05:55-03:00 |
# | 262  |   planning   | united states |       colorado       |           golden           |        4        | 2024-11-08 08:05:55-03:00 |
# | 263  |   brewpub    | united states |      tennessee       |        chattanooga         |        4        | 2024-11-08 08:05:55-03:00 |
# | 264  |    micro     | united states |       florida        |       boynton beach        |        4        | 2024-11-08 08:05:55-03:00 |
# | 265  |    micro     | united states |      washington      |         burlington         |        4        | 2024-11-08 08:05:55-03:00 |
# | 266  |    micro     | united states |       colorado       |         estes park         |        4        | 2024-11-08 08:05:55-03:00 |
# | 267  |    micro     | united states |      california      |       santa barbara        |        4        | 2024-11-08 08:05:55-03:00 |
# | 268  |   brewpub    | united states |      minnesota       |         saint paul         |        4        | 2024-11-08 08:05:55-03:00 |
# | 269  |   brewpub    | united states |     pennsylvania     |        phoenixville        |        4        | 2024-11-08 08:05:55-03:00 |
# | 270  |   brewpub    | united states |       virginia       |       fredericksburg       |        4        | 2024-11-08 08:05:55-03:00 |
# | 271  |    micro     | united states |      washington      |        walla walla         |        4        | 2024-11-08 08:05:55-03:00 |
# | 272  |   planning   | united states |        oregon        |          portland          |        4        | 2024-11-08 08:05:55-03:00 |
# | 273  |    closed    | united states |        oregon        |          portland          |        4        | 2024-11-08 08:05:55-03:00 |
# | 274  |    micro     | united states |      washington      |          poulsbo           |        4        | 2024-11-08 08:05:55-03:00 |
# | 275  |    micro     | united states |         ohio         |           dayton           |        4        | 2024-11-08 08:05:55-03:00 |
# | 276  |    micro     | united states |       michigan       |         marquette          |        4        | 2024-11-08 08:05:55-03:00 |
# | 277  |    micro     | united states |      california      |         elk grove          |        4        | 2024-11-08 08:05:55-03:00 |
# | 278  |   brewpub    | united states |    south carolina    |          columbia          |        4        | 2024-11-08 08:05:55-03:00 |
# | 279  |    micro     | united states |       florida        |      fort lauderdale       |        4        | 2024-11-08 08:05:55-03:00 |
# | 280  |    micro     | united states |        oregon        |          astoria           |        4        | 2024-11-08 08:05:55-03:00 |
# | 281  |    micro     | united states |      california      |         santa ana          |        4        | 2024-11-08 08:05:55-03:00 |
# | 282  |   brewpub    | united states |      tennessee       |         nashville          |        4        | 2024-11-08 08:05:55-03:00 |
# | 283  |   brewpub    | united states |        maine         |           bangor           |        4        | 2024-11-08 08:05:55-03:00 |
# | 284  |    micro     | united states |      california      |          richmond          |        4        | 2024-11-08 08:05:55-03:00 |
# | 285  |   brewpub    | united states |      washington      |          spokane           |        4        | 2024-11-08 08:05:55-03:00 |
# | 286  |   brewpub    | united states |       colorado       |        westminster         |        4        | 2024-11-08 08:05:55-03:00 |
# | 287  |    micro     | united states |     pennsylvania     |         lancaster          |        4        | 2024-11-08 08:05:55-03:00 |
# | 288  |    micro     | united states |       michigan       |        grand haven         |        4        | 2024-11-08 08:05:55-03:00 |
# | 289  |    closed    | united states |      washington      |        woodinville         |        4        | 2024-11-08 08:05:55-03:00 |
# | 290  |    micro     | united states |        oregon        |          medford           |        4        | 2024-11-08 08:05:55-03:00 |
# | 291  |   planning   | united states |     pennsylvania     |         pittsburgh         |        4        | 2024-11-08 08:05:55-03:00 |
# | 292  |    micro     | united states |        oregon        |        oregon city         |        4        | 2024-11-08 08:05:55-03:00 |
# | 293  |    micro     | united states |      california      |           fresno           |        4        | 2024-11-08 08:05:55-03:00 |
# | 294  |   brewpub    | united states |       arizona        |          glendale          |        4        | 2024-11-08 08:05:55-03:00 |
# | 295  |   brewpub    | united states |    north carolina    |          raleigh           |        4        | 2024-11-08 08:05:55-03:00 |
# | 296  |    micro     | united states |       arizona        |           tempe            |        4        | 2024-11-08 08:05:55-03:00 |
# | 297  |   brewpub    | united states |      california      |         long beach         |        4        | 2024-11-08 08:05:55-03:00 |
# | 298  |   brewpub    | united states |      california      |      south lake tahoe      |        4        | 2024-11-08 08:05:55-03:00 |
# | 299  |   brewpub    |   singapore   |      singapore       |         singapore          |        4        | 2024-11-08 08:05:55-03:00 |
# | 300  |    micro     | united states |      california      |          temecula          |        4        | 2024-11-08 08:05:55-03:00 |
# | 301  |    micro     | united states |      california      |         long beach         |        4        | 2024-11-08 08:05:55-03:00 |
# | 302  |    micro     | united states |       colorado       |           golden           |        4        | 2024-11-08 08:05:55-03:00 |
# | 303  |    micro     | united states |       new york       |        canandaigua         |        4        | 2024-11-08 08:05:55-03:00 |
# | 304  |    micro     | united states |     rhode island     |         providence         |        4        | 2024-11-08 08:05:55-03:00 |
# | 305  |    micro     | united states |      wisconsin       |         green bay          |        4        | 2024-11-08 08:05:55-03:00 |
# | 306  |   brewpub    | united states |       indiana        |         new albany         |        4        | 2024-11-08 08:05:55-03:00 |
# | 307  |   taproom    |    england    |     west sussex      |          horsham           |        4        | 2024-11-08 08:05:55-03:00 |
# | 308  |    micro     | united states |       new york       |        hammondsport        |        4        | 2024-11-08 08:05:55-03:00 |
# | 309  |   brewpub    | united states |      wisconsin       |         milwaukee          |        4        | 2024-11-08 08:05:55-03:00 |
# | 310  |   brewpub    | united states |       delaware       |       rehoboth beach       |        4        | 2024-11-08 08:05:55-03:00 |
# | 311  |    micro     | united states |      california      |           davis            |        4        | 2024-11-08 08:05:55-03:00 |
# | 312  |    micro     | united states |       colorado       |          lakewood          |        4        | 2024-11-08 08:05:55-03:00 |
# | 313  |    micro     | united states |      california      |        chula vista         |        4        | 2024-11-08 08:05:55-03:00 |
# | 314  |    micro     | united states |       arizona        |            mesa            |        4        | 2024-11-08 08:05:55-03:00 |
# | 315  |    micro     | united states |    south carolina    |         greenville         |        4        | 2024-11-08 08:05:55-03:00 |
# | 316  |   contract   | united states |      california      |          san jose          |        4        | 2024-11-08 08:05:55-03:00 |
# | 317  |    micro     | united states |       virginia       |        harrisonburg        |        4        | 2024-11-08 08:05:55-03:00 |
# | 318  |   brewpub    | united states |        oregon        |        grants pass         |        4        | 2024-11-08 08:05:55-03:00 |
# | 319  |    micro     | united states |      washington      |          everett           |        4        | 2024-11-08 08:05:55-03:00 |
# | 320  |   brewpub    | united states |       virginia       |          leesburg          |        4        | 2024-11-08 08:05:55-03:00 |
# | 321  |    micro     | united states |        texas         |       corpus christi       |        4        | 2024-11-08 08:05:55-03:00 |
# | 322  |    micro     | united states |       colorado       |         broomfield         |        3        | 2024-11-08 08:05:55-03:00 |
# | 323  |    micro     | united states |       illinois       |        springfield         |        3        | 2024-11-08 08:05:55-03:00 |
# | 324  |    micro     | united states |      california      |          pasadena          |        3        | 2024-11-08 08:05:55-03:00 |
# | 325  |   brewpub    | united states |      washington      |          olympia           |        3        | 2024-11-08 08:05:55-03:00 |
# | 326  |   regional   | united states |       new york       |          brooklyn          |        3        | 2024-11-08 08:05:55-03:00 |
# | 327  |   brewpub    | united states |    north carolina    |        fayetteville        |        3        | 2024-11-08 08:05:55-03:00 |
# | 328  |   planning   | united states |       virginia       |          ashburn           |        3        | 2024-11-08 08:05:55-03:00 |
# | 329  |    micro     | united states |       nebraska       |          la vista          |        3        | 2024-11-08 08:05:55-03:00 |
# | 330  |   brewpub    | united states |        texas         |         fort worth         |        3        | 2024-11-08 08:05:55-03:00 |
# | 331  |    micro     | united states |    massachusetts     |         somerville         |        3        | 2024-11-08 08:05:55-03:00 |
# | 332  |    micro     | united states |      tennessee       |         cookeville         |        3        | 2024-11-08 08:05:55-03:00 |
# | 333  |    micro     | united states |      california      |         atascadero         |        3        | 2024-11-08 08:05:55-03:00 |
# | 334  |    micro     | united states |    south carolina    |          columbia          |        3        | 2024-11-08 08:05:55-03:00 |
# | 335  |    micro     | united states |      california      |          murrieta          |        3        | 2024-11-08 08:05:55-03:00 |
# | 336  |    micro     | united states |      california      |           upland           |        3        | 2024-11-08 08:05:55-03:00 |
# | 337  |    micro     | united states |      california      |        san clemente        |        3        | 2024-11-08 08:05:55-03:00 |
# | 338  |   brewpub    | united states |       indiana        |         fort wayne         |        3        | 2024-11-08 08:05:55-03:00 |
# | 339  |    micro     | united states |      california      |          alameda           |        3        | 2024-11-08 08:05:55-03:00 |
# | 340  |    micro     | united states |        oregon        |        mcminnville         |        3        | 2024-11-08 08:05:55-03:00 |
# | 341  |    micro     | united states |      washington      |          kirkland          |        3        | 2024-11-08 08:05:55-03:00 |
# ...
# | 5021 |   brewpub    | united states |        texas         |        marble falls        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5022 |    micro     | united states |       michigan       |        frankenmuth         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5023 |   brewpub    | united states |     pennsylvania     |         bridgeport         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5024 |    micro     | united states |         ohio         |           xenia            |        1        | 2024-11-08 08:05:55-03:00 |
# | 5025 |    micro     | united states |    massachusetts     |          milford           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5026 |   brewpub    | united states |     pennsylvania     |         rochester          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5027 |   brewpub    | united states |       new york       |        morrisville         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5028 |    micro     | united states |      california      |           ramona           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5029 |    micro     | united states |         ohio         |           medway           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5030 |    micro     | united states |       new york       |        pine island         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5031 |    micro     | united states |    new hampshire     |          henniker          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5032 |    micro     | united states |        texas         |           keller           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5033 |  proprietor  | united states |      california      |          stockton          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5034 |  proprietor  | united states |         ohio         |           dayton           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5035 |    micro     | united states |     connecticut      |        east granby         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5036 |    closed    | united states |      wisconsin       |        new richmond        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5037 |    micro     | united states |        texas         |          lubbock           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5038 |    micro     | united states |      new mexico      |         los alamos         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5039 |    micro     | united states |    massachusetts     |          ipswich           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5040 |    micro     | united states |       new york       |       honeoye falls        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5041 |  proprietor  | united states |       illinois       |         villa park         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5042 |   brewpub    | united states |       georgia        |           dalton           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5043 |   brewpub    | united states |       colorado       |         lake city          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5044 |    micro     | united states |       vermont        |         middlebury         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5045 |    micro     | united states |         iowa         |         le claire          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5046 |   brewpub    | united states |      wisconsin       |           verona           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5047 |    micro     | united states |     mississippi      |          natchez           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5048 |   brewpub    | united states |       michigan       |         plainwell          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5049 |    micro     | united states |       illinois       |          homewood          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5050 |   brewpub    | united states |       maryland       |        gaithersburg        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5051 |   brewpub    | united states |       nebraska       |        north platte        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5052 |    micro     | united states |        maine         |         skowhegan          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5053 |    micro     | united states |      wisconsin       |          merrill           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5054 |   brewpub    | united states |      washington      |          republic          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5055 |    micro     |    ireland    |       kildare        |         celbridge          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5056 |   brewpub    | united states |       vermont        |          norwich           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5057 |    micro     | united states |      new jersey      |         burlington         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5058 |    micro     | united states |    new hampshire     |           conway           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5059 |    micro     | united states |      california      |          belmont           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5060 |    micro     | united states |        oregon        |           dundee           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5061 |   brewpub    | united states |      wisconsin       |         greendale          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5062 |    micro     | united states |       illinois       |         teutopolis         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5063 |   planning   | united states |      tennessee       |          townsend          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5064 |   brewpub    | united states |       michigan       |         northport          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5065 |   brewpub    | united states |      minnesota       |            ely             |        1        | 2024-11-08 08:05:55-03:00 |
# | 5066 |   brewpub    | united states |       new york       |        trumansburg         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5067 |    micro     | united states |       new york       |         watertown          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5068 |   planning   | united states |     pennsylvania     |           export           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5069 |    micro     | united states |      california      |           bishop           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5070 |   brewpub    | united states |       new york       |        cheektowaga         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5071 |   planning   | united states |       florida        |           oviedo           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5072 |    micro     | united states |        maine         |          monmouth          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5073 |   planning   | united states |         ohio         |        mount vernon        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5074 |   planning   | united states |       new york       |           hector           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5075 |   planning   | united states |      wisconsin       |         fall creek         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5076 |   regional   | united states |      washington      |         ellensburg         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5077 |    micro     | united states |      california      |      el dorado hills       |        1        | 2024-11-08 08:05:55-03:00 |
# | 5078 |   brewpub    | united states |      washington      |          quilcene          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5079 |   brewpub    | united states |       colorado       |          edwards           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5080 |   brewpub    |  south korea  |   gyeongsangnamdo    |         namhaegun          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5081 |   brewpub    |  south korea  |      gyeonggido      |       dongducheonsi        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5082 |   brewpub    | united states |       virginia       |          bristol           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5083 |    micro     | united states |       florida        |         plant city         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5084 |   brewpub    | united states |       michigan       |          paradise          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5085 |   brewpub    | united states |       georgia        |       stone mountain       |        1        | 2024-11-08 08:05:55-03:00 |
# | 5086 |   planning   | united states |      washington      |        leavenworth         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5087 |   planning   | united states |      california      |         inglewood          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5088 |   contract   | united states |       indiana        |         batesville         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5089 |   brewpub    | united states |     pennsylvania     |          bristol           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5090 |   brewpub    | united states |     rhode island     |        block island        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5091 |   brewpub    | united states |       missouri       |     excelsior springs      |        1        | 2024-11-08 08:05:55-03:00 |
# | 5092 |   brewpub    | united states |       new york       |           albany           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5093 |   planning   | united states |       new york       |       college point        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5094 |   brewpub    | united states |    south carolina    |           greer            |        1        | 2024-11-08 08:05:55-03:00 |
# | 5095 |   brewpub    | united states |      california      |           cotati           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5096 |    micro     | united states |    south carolina    |        myrtle beach        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5097 |    closed    | united states |       colorado       |     greenwood village      |        1        | 2024-11-08 08:05:55-03:00 |
# | 5098 |    micro     | united states |      wisconsin       |         manitowoc          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5099 |    micro     |    ireland    |        offaly        |          kinnitty          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5100 |    micro     | united states |        kansas        |         mcpherson          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5101 |    micro     | united states |      california      |         inglewood          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5102 |   regional   | united states |      wisconsin       |           verona           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5103 |   planning   | united states |         ohio         |          newbury           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5104 |   contract   | united states |      new jersey      |      ridgefield park       |        1        | 2024-11-08 08:05:55-03:00 |
# | 5105 |   brewpub    | united states |      new mexico      |         angel fire         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5106 |    micro     | united states |      wisconsin       |         east troy          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5107 |   planning   | united states |     connecticut      |          winsted           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5108 |    micro     | united states |     connecticut      |        east hampton        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5109 |    micro     | united states |    north carolina    |       morehead city        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5110 |    micro     | united states |      california      |         santa cruz         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5111 |   brewpub    | united states |       illinois       |       downers grove        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5112 |   brewpub    | united states |     pennsylvania     |          venango           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5113 |   contract   | united states |       arkansas       |        fayetteville        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5114 |    micro     | united states |       illinois       |          wauconda          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5115 |    micro     | united states |         ohio         |         granville          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5116 |   brewpub    | united states |       michigan       |     saint clair shores     |        1        | 2024-11-08 08:05:55-03:00 |
# | 5117 |   planning   | united states |         ohio         |         lancaster          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5118 |    micro     | united states |         ohio         |          blue ash          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5119 |   planning   | united states |       georgia        |           evans            |        1        | 2024-11-08 08:05:55-03:00 |
# | 5120 |    micro     | united states |       alabama        |          opelika           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5121 |    micro     | united states |         ohio         |        centerville         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5122 |    micro     |    ireland    |        offaly        |          banagher          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5123 |    micro     | united states |    massachusetts     |         nantucket          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5124 |    micro     | united states |    new hampshire     |           salem            |        1        | 2024-11-08 08:05:55-03:00 |
# | 5125 |   planning   | united states |         ohio         |       mount victory        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5126 |   planning   | united states |       indiana        |         bloomfield         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5127 |   planning   | united states |      tennessee       |         manchester         |        1        | 2024-11-08 08:05:55-03:00 |
# | 5128 |   planning   | united states |    north carolina    |       winston salem        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5129 |    micro     | united states |         ohio         |       bellefontaine        |        1        | 2024-11-08 08:05:55-03:00 |
# | 5130 |    micro     | united states |        alaska        |          girdwood          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5131 |    micro     | united states |      minnesota       |          hallock           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5132 |    micro     |  isle of man  |        middle        |          braddan           |        1        | 2024-11-08 08:05:55-03:00 |
# | 5133 |    micro     |    france     |    bouche du rhne    |         vitrolles          |        1        | 2024-11-08 08:05:55-03:00 |
# | 5134 |    micro     |  isle of man  |        middle        |          kewaigue          |        1        | 2024-11-08 08:05:55-03:00 |
# +------+--------------+---------------+----------------------+----------------------------+-----------------+---------------------------+
# Conexão com o DuckDB fechada.

# %%
from IPython.display import display

# %%
from tabulate import tabulate

def display_result(result):
    print(tabulate(result, headers='keys', tablefmt='pretty'))

# %%
def display_result(result):
    print(result.to_markdown())

# %% [markdown]
# ## Abordagem -- Pega files boto via boto e le com Duck

# %%
import boto3
import duckdb
import pandas as pd
import json
from resources.utils.utils import load_config, print_header

# Carregar configurações
config = load_config()
_minio_endpoint_url = config["minio_dev"]["endpoint_url"]
_minio_access_key = config["minio_dev"]["access_key"]
_minio_secret_key = config["minio_dev"]["secret_key"]
_storage_brew_bucket = config["storages"]["brew_bucket"]["name"]
_storage_brew_landing = config["storages"]["brew_landing_key"]["lading"]

# Mensagem de início
print_header("INICIANDO TESTE DE CONEXÃO COM MINIO E DUCKDB")

# Configuração do MinIO (ou S3)
s3_client = boto3.client(
    's3',
    endpoint_url=_minio_endpoint_url,
    aws_access_key_id=_minio_access_key,
    aws_secret_access_key=_minio_secret_key
)

# Lista de arquivos JSON no MinIO (S3)
response = s3_client.list_objects_v2(Bucket=_storage_brew_bucket, Prefix=_storage_brew_landing)
files = [content['Key'] for content in response.get('Contents', [])]
print("Arquivos encontrados:", files)

# Conexão com DuckDB
conn = duckdb.connect(database=':memory:')

# Função para carregar dados JSON do S3 para DuckDB
def load_json_to_duckdb(file_key):
    try:
        # Baixar o arquivo JSON do MinIO
        response = s3_client.get_object(Bucket=_storage_brew_bucket, Key=file_key)
        content = response['Body'].read().decode('utf-8')
        
        # Carregar o conteúdo JSON como lista de dicionários
        data = json.loads(content)  # Garante que o conteúdo seja lido como uma lista de registros JSON
        df = pd.DataFrame(data)  # Converter para DataFrame do pandas
        
        # Inserir o DataFrame no DuckDB
        conn.execute("CREATE TABLE IF NOT EXISTS bronze_data AS SELECT * FROM df LIMIT 0")  # Estrutura da tabela
        conn.execute("INSERT INTO bronze_data SELECT * FROM df")
        
    except Exception as e:
        print(f"Erro ao carregar {file_key} para o DuckDB: {e}")

# Carregar todos os arquivos JSON encontrados no MinIO para o DuckDB
for file in files:
    print(f"Carregando {file} para o DuckDB...")
    load_json_to_duckdb(file)

# Consultas de exemplo no DuckDB
print("\nExemplo de consultas no DuckDB:")
print(conn.execute("SELECT * FROM bronze_data LIMIT 10;").fetchdf())  # Seleciona os primeiros 10 registros
print(conn.execute("SELECT COUNT(*) as total_records FROM bronze_data;").fetchdf())  # Conta o total de registros
print(conn.execute("SELECT DISTINCT country FROM bronze_data;").fetchdf())  # Lista de países distintos
# Out:
# ************************************************************
# *                                                          *
# *  >>> INICIANDO TESTE DE CONEXÃO COM MINIO E DUCKDB <<<   *
# *                                                          *
# ************************************************************
# Arquivos encontrados: ['bronze/PART_1_AT_2024_11_07.json', 'bronze/PART_2_AT_2024_11_07.json', 'bronze/PART_3_AT_2024_11_07.json', 'bronze/PART_4_AT_2024_11_07.json', 'bronze/PART_5_AT_2024_11_07.json', 'bronze/PART_6_AT_2024_11_07.json', 'bronze/PART_7_AT_2024_11_07.json', 'bronze/PART_8_AT_2024_11_07.json', 'bronze/PART_9_AT_2024_11_07.json']
# Carregando bronze/PART_1_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_2_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_3_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_4_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_5_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_6_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_7_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_8_AT_2024_11_07.json para o DuckDB...
# Carregando bronze/PART_9_AT_2024_11_07.json para o DuckDB...
#
# Exemplo de consultas no DuckDB:
#                                      id                             name  \
# 0  5128df48-79fc-4f0f-8b52-d06be54d0cec                 (405) Brewing Co
# 1  9c5a66c8-cc13-416f-a5d9-0a769c87d318                 (512) Brewing Co
# 2  34e8c68b-6146-453f-a4b9-1f6cd99a5ada          1 of Us Brewing Company
# 3  ef970757-fe42-416f-931d-722451f1f59c             10 Barrel Brewing Co
# 4  6d14b220-8926-4521-8d19-b98a2d6ec3db             10 Barrel Brewing Co
# 5  e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2             10 Barrel Brewing Co
# 6  e432899b-7f58-455f-9c7b-9a6e2130a1e0             10 Barrel Brewing Co
# 7  9f1852da-c312-42da-9a31-097bac81c4c0  10 Barrel Brewing Co - Bend Pub
# 8  ea4f30c0-bce6-416b-8904-fab4055a7362     10 Barrel Brewing Co - Boise
# 9  1988eb86-f0a2-4674-ba04-02454efa0d31    10 Barrel Brewing Co - Denver
#
#   brewery_type                    address_1 address_2 address_3  \
# 0        micro               1716 Topeka St      None      None
# 1        micro        407 Radam Ln Ste F200      None      None
# 2        micro          8100 Washington Ave      None      None
# 3        large                    1501 E St      None      None
# 4        large                62970 18th St      None      None
# 5        large  1135 NW Galveston Ave Ste B      None      None
# 6        large          1411 NW Flanders St      None      None
# 7        large             62950 NE 18th St      None      None
# 8        large             826 W Bannock St      None      None
# 9        large               2620 Walnut St      None      None
#
#              city state_province postal_code        country  \
# 0          Norman       Oklahoma  73069-8224  United States
# 1          Austin          Texas  78745-1197  United States
# 2  Mount Pleasant      Wisconsin  53406-3920  United States
# 3       San Diego     California  92101-6618  United States
# 4            Bend         Oregon  97701-9847  United States
# 5            Bend         Oregon  97703-2465  United States
# 6        Portland         Oregon  97209-2620  United States
# 7            Bend         Oregon       97701  United States
# 8           Boise          Idaho  83702-5857  United States
# 9          Denver       Colorado  80205-2231  United States
#
#             longitude           latitude       phone  \
# 0        -97.46818222        35.25738891  4058160490
# 1                None               None  5129211545
# 2  -87.88336350209435  42.72010826899558  2624847553
# 3         -117.129593          32.714813  6195782311
# 4         -121.281706        44.08683531  5415851007
# 5        -121.3288021         44.0575649  5415851007
# 6        -122.6855056         45.5259786  5032241700
# 7        -121.2809536         44.0912109  5415851007
# 8         -116.202929          43.618516  2083445870
# 9        -104.9853655         39.7592508  7205738992
#
#                     website_url       state                       street
# 0     http://www.405brewing.com    Oklahoma               1716 Topeka St
# 1     http://www.512brewing.com       Texas        407 Radam Ln Ste F200
# 2  https://www.1ofusbrewing.com   Wisconsin          8100 Washington Ave
# 3           http://10barrel.com  California                    1501 E St
# 4       http://www.10barrel.com      Oregon                62970 18th St
# 5                          None      Oregon  1135 NW Galveston Ave Ste B
# 6       http://www.10barrel.com      Oregon          1411 NW Flanders St
# 7                          None      Oregon             62950 NE 18th St
# 8       http://www.10barrel.com       Idaho             826 W Bannock St
# 9                          None    Colorado               2620 Walnut St
#    total_records
# 0           8355
#            country
# 0      South Korea
# 1           Poland
# 2           France
# 3    United States
# 4          Ireland
# 5          Germany
# 6           Sweden
# 7    United States
# 8      Isle of Man
# 9          Austria
# 10         England
# 11       Singapore
# 12        Portugal
# 13        Scotland

# %%
import os
import boto3
import duckdb

# Configurações do MinIO
minio_endpoint = "http://10.96.188.1:9000"
minio_access_key = "miniouser"
minio_secret_key = "miniosecret"
brew_bucket = "lakehouse"
brew_prefix = "bronze/"

# Configuração do cliente MinIO com boto3
s3_client = boto3.client(
    's3',
    endpoint_url=minio_endpoint,
    aws_access_key_id=minio_access_key,
    aws_secret_access_key=minio_secret_key
)

# Conexão com DuckDB em memória
conn = duckdb.connect(database=':memory:')
table_name = "bronze_data"

# Função para baixar e carregar JSON no DuckDB
def load_json_to_duckdb(file_key):
    """Baixa o arquivo JSON do MinIO e carrega no DuckDB."""
    local_file_path = file_key.split('/')[-1]

    # Baixa o arquivo JSON do MinIO
    s3_client.download_file(brew_bucket, file_key, local_file_path)
    print(f"Arquivo {file_key} baixado com sucesso para {local_file_path}")

    try:
        # Insere os dados JSON na tabela DuckDB
        conn.execute(f"INSERT INTO {table_name} SELECT * FROM read_json_auto('{local_file_path}')")
        print(f"Dados do arquivo '{local_file_path}' carregados com sucesso no DuckDB.")

    except Exception as e:
        print(f"Erro ao carregar dados no DuckDB: \n{e}")

    finally:
        # Exclui o arquivo temporário
        os.remove(local_file_path)
        print(f"Arquivo temporário {local_file_path} removido.")

# Cria a tabela no DuckDB com base na estrutura do primeiro arquivo
response = s3_client.list_objects_v2(Bucket=brew_bucket, Prefix=brew_prefix)
files = [content['Key'] for content in response.get('Contents', []) if content['Key'].endswith('.json')]

# Carrega o primeiro arquivo para definir a estrutura da tabela
first_file = files[0]
local_file_path = first_file.split('/')[-1]
s3_client.download_file(brew_bucket, first_file, local_file_path)
conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM read_json_auto('{local_file_path}')")
os.remove(local_file_path)
print(f"Tabela '{table_name}' criada com sucesso no DuckDB.")

# Carrega o restante dos arquivos na tabela
for file_key in files[1:]:  # Ignora o primeiro arquivo que já foi carregado
    load_json_to_duckdb(file_key)

# Consultas de exemplo no DuckDB
try:
    # Contagem total de registros
    total_records = conn.execute(f"SELECT COUNT(*) as total_records FROM {table_name};").fetchdf()
    print("\nTotal de registros:", total_records)

    # Listar países distintos
    distinct_countries = conn.execute(f"SELECT DISTINCT country FROM {table_name};").fetchdf()
    print("\nPaíses distintos:")
    print(distinct_countries)

except Exception as e:
    print(f"Erro ao executar as consultas: \n{e}")

finally:
    conn.close()
# Out:
# Tabela 'bronze_data' criada com sucesso no DuckDB.
# Arquivo bronze/PART_2_AT_2024_11_07.json baixado com sucesso para PART_2_AT_2024_11_07.json
# Dados do arquivo 'PART_2_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_2_AT_2024_11_07.json removido.
# Arquivo bronze/PART_3_AT_2024_11_07.json baixado com sucesso para PART_3_AT_2024_11_07.json
# Dados do arquivo 'PART_3_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_3_AT_2024_11_07.json removido.
# Arquivo bronze/PART_4_AT_2024_11_07.json baixado com sucesso para PART_4_AT_2024_11_07.json
# Dados do arquivo 'PART_4_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_4_AT_2024_11_07.json removido.
# Arquivo bronze/PART_5_AT_2024_11_07.json baixado com sucesso para PART_5_AT_2024_11_07.json
# Dados do arquivo 'PART_5_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_5_AT_2024_11_07.json removido.
# Arquivo bronze/PART_6_AT_2024_11_07.json baixado com sucesso para PART_6_AT_2024_11_07.json
# Dados do arquivo 'PART_6_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_6_AT_2024_11_07.json removido.
# Arquivo bronze/PART_7_AT_2024_11_07.json baixado com sucesso para PART_7_AT_2024_11_07.json
# Dados do arquivo 'PART_7_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_7_AT_2024_11_07.json removido.
# Arquivo bronze/PART_8_AT_2024_11_07.json baixado com sucesso para PART_8_AT_2024_11_07.json
# Dados do arquivo 'PART_8_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_8_AT_2024_11_07.json removido.
# Arquivo bronze/PART_9_AT_2024_11_07.json baixado com sucesso para PART_9_AT_2024_11_07.json
# Dados do arquivo 'PART_9_AT_2024_11_07.json' carregados com sucesso no DuckDB.
# Arquivo temporário PART_9_AT_2024_11_07.json removido.
#
# Total de registros:    total_records
# 0           8355
#
# Países distintos:
#            country
# 0      South Korea
# 1           Poland
# 2           France
# 3    United States
# 4          Ireland
# 5          Germany
# 6           Sweden
# 7         Scotland
# 8         Portugal
# 9          England
# 10       Singapore
# 11   United States
# 12     Isle of Man
# 13         Austria

# %% [markdown]
# ## parquet rodando torto silver

# %%
import os
import boto3
import duckdb

# Configurações do MinIO
minio_endpoint = "http://10.96.188.1:9000"
minio_access_key = "miniouser"
minio_secret_key = "miniosecret"
brew_bucket = "lakehouse"
brew_prefix = "silver/"  # Mude para "bronze/" se precisar

# Configuração do cliente MinIO com boto3
s3_client = boto3.client(
    's3',
    endpoint_url=minio_endpoint,
    aws_access_key_id=minio_access_key,
    aws_secret_access_key=minio_secret_key
)

# Conexão com DuckDB em memória e carregamento dos módulos necessários
conn = duckdb.connect(database=':memory:')
conn.execute("INSTALL httpfs;")
conn.execute("LOAD httpfs;")
conn.execute("INSTALL parquet;")  # Certifique-se de que o módulo Parquet está instalado
conn.execute("LOAD parquet;")
table_name = "silver_data"

# Função para baixar arquivos Parquet e carregar no DuckDB
def load_parquet_to_duckdb(file_key):
    """Baixa o arquivo Parquet do MinIO e carrega no DuckDB."""
    local_file_path = file_key.split('/')[-1]

    # Baixa o arquivo Parquet do MinIO
    s3_client.download_file(brew_bucket, file_key, local_file_path)
    print(f"Arquivo {file_key} baixado com sucesso para {local_file_path}")

    try:
        # Insere os dados do Parquet na tabela DuckDB
        conn.execute(f"INSERT INTO {table_name} SELECT * FROM read_parquet('{local_file_path}')")
        print(f"Dados do arquivo '{local_file_path}' carregados com sucesso no DuckDB.")

    except Exception as e:
        print(f"Erro ao carregar dados no DuckDB: \n{e}")

    finally:
        # Exclui o arquivo temporário
        os.remove(local_file_path)
        print(f"Arquivo temporário {local_file_path} removido.")

# Lista e baixa todos os arquivos Parquet no bucket especificado
response = s3_client.list_objects_v2(Bucket=brew_bucket, Prefix=brew_prefix)
files = [content['Key'] for content in response.get('Contents', []) if content['Key'].endswith('.parquet')]

# Inicializa a tabela no DuckDB com o primeiro arquivo para definir a estrutura
first_file = files[0]
local_file_path = first_file.split('/')[-1]
s3_client.download_file(brew_bucket, first_file, local_file_path)
conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM read_parquet('{local_file_path}')")
os.remove(local_file_path)
print(f"Tabela '{table_name}' criada com sucesso no DuckDB.")

# Carrega o restante dos arquivos na tabela
for file_key in files[1:]:  # Ignora o primeiro arquivo que já foi carregado
    load_parquet_to_duckdb(file_key)

# Consultas de exemplo no DuckDB
try:
    # Contagem total de registros
    total_records = conn.execute(f"SELECT COUNT(*) as total_records FROM {table_name};").fetchdf()
    print("\nTotal de registros:", total_records)

    # Listar países distintos
    distinct_countries = conn.execute(f"SELECT DISTINCT country FROM {table_name};").fetchdf()
    print("\nPaíses distintos:")
    print(distinct_countries)

except Exception as e:
    print(f"Erro ao executar as consultas: \n{e}")

finally:
    conn.close()
# Out:
# Tabela 'silver_data' criada com sucesso no DuckDB.
# Arquivo silver/country=england/part-00000-f9be67f8-6a4b-4ab6-acbb-cded77a703da.c000.snappy.parquet baixado com sucesso para part-00000-f9be67f8-6a4b-4ab6-acbb-cded77a703da.c000.snappy.parquet
# Dados do arquivo 'part-00000-f9be67f8-6a4b-4ab6-acbb-cded77a703da.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-f9be67f8-6a4b-4ab6-acbb-cded77a703da.c000.snappy.parquet removido.
# Arquivo silver/country=france/part-00000-cc7c7abe-7004-4d5d-9402-006c49d578f3.c000.snappy.parquet baixado com sucesso para part-00000-cc7c7abe-7004-4d5d-9402-006c49d578f3.c000.snappy.parquet
# Dados do arquivo 'part-00000-cc7c7abe-7004-4d5d-9402-006c49d578f3.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-cc7c7abe-7004-4d5d-9402-006c49d578f3.c000.snappy.parquet removido.
# Arquivo silver/country=germany/part-00000-ef230031-25a4-46bf-8d6e-01240ee45dab.c000.snappy.parquet baixado com sucesso para part-00000-ef230031-25a4-46bf-8d6e-01240ee45dab.c000.snappy.parquet
# Dados do arquivo 'part-00000-ef230031-25a4-46bf-8d6e-01240ee45dab.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-ef230031-25a4-46bf-8d6e-01240ee45dab.c000.snappy.parquet removido.
# Arquivo silver/country=ireland/part-00000-3e6fb001-c4c1-4335-910c-e6eaf419a95e.c000.snappy.parquet baixado com sucesso para part-00000-3e6fb001-c4c1-4335-910c-e6eaf419a95e.c000.snappy.parquet
# Dados do arquivo 'part-00000-3e6fb001-c4c1-4335-910c-e6eaf419a95e.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-3e6fb001-c4c1-4335-910c-e6eaf419a95e.c000.snappy.parquet removido.
# Arquivo silver/country=isle of man/part-00000-1187f701-7c5c-49cc-931f-2b0661f23b37.c000.snappy.parquet baixado com sucesso para part-00000-1187f701-7c5c-49cc-931f-2b0661f23b37.c000.snappy.parquet
# Dados do arquivo 'part-00000-1187f701-7c5c-49cc-931f-2b0661f23b37.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-1187f701-7c5c-49cc-931f-2b0661f23b37.c000.snappy.parquet removido.
# Arquivo silver/country=poland/part-00000-8e28fe9b-4be7-4de2-996f-714d6bda34d3.c000.snappy.parquet baixado com sucesso para part-00000-8e28fe9b-4be7-4de2-996f-714d6bda34d3.c000.snappy.parquet
# Dados do arquivo 'part-00000-8e28fe9b-4be7-4de2-996f-714d6bda34d3.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-8e28fe9b-4be7-4de2-996f-714d6bda34d3.c000.snappy.parquet removido.
# Arquivo silver/country=portugal/part-00000-6803d7f9-00cf-4a3c-96d2-4520fc95a6cc.c000.snappy.parquet baixado com sucesso para part-00000-6803d7f9-00cf-4a3c-96d2-4520fc95a6cc.c000.snappy.parquet
# Dados do arquivo 'part-00000-6803d7f9-00cf-4a3c-96d2-4520fc95a6cc.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-6803d7f9-00cf-4a3c-96d2-4520fc95a6cc.c000.snappy.parquet removido.
# Arquivo silver/country=scotland/part-00000-5621b1b3-e412-4357-a3dc-0ea90859f67e.c000.snappy.parquet baixado com sucesso para part-00000-5621b1b3-e412-4357-a3dc-0ea90859f67e.c000.snappy.parquet
# Dados do arquivo 'part-00000-5621b1b3-e412-4357-a3dc-0ea90859f67e.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-5621b1b3-e412-4357-a3dc-0ea90859f67e.c000.snappy.parquet removido.
# Arquivo silver/country=singapore/part-00000-eb126c7d-2a4b-4a34-a05d-2269f088bddc.c000.snappy.parquet baixado com sucesso para part-00000-eb126c7d-2a4b-4a34-a05d-2269f088bddc.c000.snappy.parquet
# Dados do arquivo 'part-00000-eb126c7d-2a4b-4a34-a05d-2269f088bddc.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-eb126c7d-2a4b-4a34-a05d-2269f088bddc.c000.snappy.parquet removido.
# Arquivo silver/country=south korea/part-00000-ab56c826-c5ec-416f-80b1-5114f6594712.c000.snappy.parquet baixado com sucesso para part-00000-ab56c826-c5ec-416f-80b1-5114f6594712.c000.snappy.parquet
# Dados do arquivo 'part-00000-ab56c826-c5ec-416f-80b1-5114f6594712.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-ab56c826-c5ec-416f-80b1-5114f6594712.c000.snappy.parquet removido.
# Arquivo silver/country=sweden/part-00000-2bcf6258-f04e-41f3-9d79-8467e59fb83a.c000.snappy.parquet baixado com sucesso para part-00000-2bcf6258-f04e-41f3-9d79-8467e59fb83a.c000.snappy.parquet
# Dados do arquivo 'part-00000-2bcf6258-f04e-41f3-9d79-8467e59fb83a.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-2bcf6258-f04e-41f3-9d79-8467e59fb83a.c000.snappy.parquet removido.
# Arquivo silver/country=united states/part-00000-e295923a-7724-4b07-b651-0379be8f512b.c000.snappy.parquet baixado com sucesso para part-00000-e295923a-7724-4b07-b651-0379be8f512b.c000.snappy.parquet
# Dados do arquivo 'part-00000-e295923a-7724-4b07-b651-0379be8f512b.c000.snappy.parquet' carregados com sucesso no DuckDB.
# Arquivo temporário part-00000-e295923a-7724-4b07-b651-0379be8f512b.c000.snappy.parquet removido.
#
# Total de registros:    total_records
# 0           8355
# Erro ao executar as consultas:
# Binder Error: Referenced column "country" not found in FROM clause!
# Candidate bindings: "silver_data.city", "silver_data.longitude", "silver_data.phone"
# LINE 1: SELECT DISTINCT country FROM silver_data;
#                         ^

# %% [markdown]
# ## delta nao rodando

# %%
import os
import boto3
import duckdb

# Configurações do MinIO
minio_endpoint = "http://10.96.188.1:9000"
minio_access_key = "miniouser"
minio_secret_key = "miniosecret"
brew_bucket = "lakehouse"
brew_prefix = "silver/"  # Mude para "bronze/" se precisar

# Configuração do cliente MinIO com boto3
s3_client = boto3.client(
    's3',
    endpoint_url=minio_endpoint,
    aws_access_key_id=minio_access_key,
    aws_secret_access_key=minio_secret_key
)

# Conexão com DuckDB em memória e carregamento dos módulos necessários
conn = duckdb.connect(database=':memory:')
conn.execute("INSTALL httpfs;")
conn.execute("LOAD httpfs;")
conn.execute("INSTALL delta;")
conn.execute("LOAD delta;")
table_name = "silver_data"

# Função para baixar arquivos Delta e carregar no DuckDB
def load_delta_to_duckdb(file_key):
    """Baixa o arquivo Delta do MinIO e carrega no DuckDB."""
    local_file_path = file_key.split('/')[-1]

    # Baixa o arquivo Delta do MinIO
    s3_client.download_file(brew_bucket, file_key, local_file_path)
    print(f"Arquivo {file_key} baixado com sucesso para {local_file_path}")

    try:
        # Insere os dados do Delta na tabela DuckDB
        conn.execute(f"INSERT INTO {table_name} SELECT * FROM read_delta('{local_file_path}')")
        print(f"Dados do arquivo '{local_file_path}' carregados com sucesso no DuckDB.")

    except Exception as e:
        print(f"Erro ao carregar dados no DuckDB: \n{e}")

    finally:
        # Exclui o arquivo temporário
        os.remove(local_file_path)
        print(f"Arquivo temporário {local_file_path} removido.")

# Lista e baixa todos os arquivos Delta
response = s3_client.list_objects_v2(Bucket=brew_bucket, Prefix=brew_prefix)
files = [content['Key'] for content in response.get('Contents', []) if content['Key'].endswith('.parquet')]

# Inicializa a tabela no DuckDB com o primeiro arquivo para definir a estrutura
first_file = files[0]
local_file_path = first_file.split('/')[-1]
s3_client.download_file(brew_bucket, first_file, local_file_path)
conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM read_delta('{local_file_path}')")
os.remove(local_file_path)
print(f"Tabela '{table_name}' criada com sucesso no DuckDB.")

# Carrega o restante dos arquivos na tabela
for file_key in files[1:]:  # Ignora o primeiro arquivo que já foi carregado
    load_delta_to_duckdb(file_key)

# Consultas de exemplo no DuckDB
try:
    # Contagem total de registros
    total_records = conn.execute(f"SELECT COUNT(*) as total_records FROM {table_name};").fetchdf()
    print("\nTotal de registros:", total_records)

    # Listar países distintos
    distinct_countries = conn.execute(f"SELECT DISTINCT country FROM {table_name};").fetchdf()
    print("\nPaíses distintos:")
    print(distinct_countries)

except Exception as e:
    print(f"Erro ao executar as consultas: \n{e}")

finally:
    conn.close()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[35], line 58
#      56 local_file_path = first_file.split('/')[-1]
#      57 s3_client.download_file(brew_bucket, first_file, local_file_path)
# ---> 58 conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM read_delta('{local_file_path}')")
#      59 os.remove(local_file_path)
#      60 print(f"Tabela '{table_name}' criada com sucesso no DuckDB.")
#
# CatalogException: Catalog Error: Table Function with name read_delta does not exist!
# Did you mean "read_parquet"?
# LINE 1: ...ATE TABLE silver_data AS SELECT * FROM read_delta('part-00000-deeb568d-3d56-4c...
#                                                   ^

# %% [markdown]
# ## DuckDb fudendo pra ler delta.

# %%
import os
import boto3
import duckdb

# Configurações MinIO e Delta Lake
minio_endpoint = "http://10.96.188.1:9000"
minio_access_key = "miniouser"
minio_secret_key = "miniosecret"
bucket_name = "lakehouse"
prefix = "silver/"

# Inicializar cliente MinIO (via boto3)
s3_client = boto3.client(
    's3',
    endpoint_url=minio_endpoint,
    aws_access_key_id=minio_access_key,
    aws_secret_access_key=minio_secret_key
)

# Função para baixar os arquivos, mantendo a estrutura de pastas
def download_files_from_s3(prefix, local_base_dir="silver_data"):
    response = s3_client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)
    for obj in response.get('Contents', []):
        file_key = obj['Key']
        local_path = os.path.join(local_base_dir, file_key.replace(prefix, ""))  # Mantém a estrutura de pastas
        os.makedirs(os.path.dirname(local_path), exist_ok=True)
        s3_client.download_file(bucket_name, file_key, local_path)
        print(f"Baixado: {local_path}")

# Baixar a estrutura completa
download_files_from_s3(prefix)

# Conexão com DuckDB em memória
conn = duckdb.connect(database=':memory:')
conn.execute("INSTALL httpfs;")
conn.execute("LOAD httpfs;")

# Diretório local com os arquivos baixados
local_data_path = "silver_data/silver"

# Função para carregar todos os arquivos Parquet do diretório no DuckDB
def load_parquet_files_to_duckdb(base_dir, table_name="silver_data"):
    # Lista para armazenar os caminhos dos arquivos Parquet
    parquet_files = []
    for root, _, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".parquet"):
                parquet_files.append(os.path.join(root, file))

    # Cria a tabela com base no primeiro arquivo Parquet e insere o restante
    if parquet_files:
        print(f"Carregando {len(parquet_files)} arquivos Parquet para DuckDB.")
        
        # Cria a tabela com o primeiro arquivo Parquet
        conn.execute(f"CREATE TABLE {table_name} AS SELECT * FROM read_parquet('{parquet_files[0]}')")
        
        # Insere os dados dos arquivos restantes
        for parquet_file in parquet_files[1:]:
            conn.execute(f"INSERT INTO {table_name} SELECT * FROM read_parquet('{parquet_file}')")
            print(f"Inserido: {parquet_file}")
    else:
        print("Nenhum arquivo Parquet encontrado.")

# Carregar todos os arquivos Parquet no DuckDB
load_parquet_files_to_duckdb(local_data_path)

# Consultas de exemplo no DuckDB
try:
    # Contagem total de registros
    total_records = conn.execute("SELECT COUNT(*) as total_records FROM silver_data;").fetchdf()
    print("\nTotal de registros:", total_records)

    # Listar países distintos
    distinct_countries = conn.execute("SELECT DISTINCT country FROM silver_data;").fetchdf()
    print("\nPaíses distintos:")
    print(distinct_countries)

except Exception as e:
    print(f"Erro ao executar as consultas: \n{e}")

finally:
    conn.close()
# Out:
# Baixado: silver_data/_delta_log/00000000000000000000.json
# Baixado: silver_data/country=austria/part-00000-deeb568d-3d56-4c54-980d-8fcf2f29758f.c000.snappy.parquet
# Baixado: silver_data/country=england/part-00000-f9be67f8-6a4b-4ab6-acbb-cded77a703da.c000.snappy.parquet
# Baixado: silver_data/country=france/part-00000-cc7c7abe-7004-4d5d-9402-006c49d578f3.c000.snappy.parquet
# Baixado: silver_data/country=germany/part-00000-ef230031-25a4-46bf-8d6e-01240ee45dab.c000.snappy.parquet
# Baixado: silver_data/country=ireland/part-00000-3e6fb001-c4c1-4335-910c-e6eaf419a95e.c000.snappy.parquet
# Baixado: silver_data/country=isle of man/part-00000-1187f701-7c5c-49cc-931f-2b0661f23b37.c000.snappy.parquet
# Baixado: silver_data/country=poland/part-00000-8e28fe9b-4be7-4de2-996f-714d6bda34d3.c000.snappy.parquet
# Baixado: silver_data/country=portugal/part-00000-6803d7f9-00cf-4a3c-96d2-4520fc95a6cc.c000.snappy.parquet
# Baixado: silver_data/country=scotland/part-00000-5621b1b3-e412-4357-a3dc-0ea90859f67e.c000.snappy.parquet
# Baixado: silver_data/country=singapore/part-00000-eb126c7d-2a4b-4a34-a05d-2269f088bddc.c000.snappy.parquet
# Baixado: silver_data/country=south korea/part-00000-ab56c826-c5ec-416f-80b1-5114f6594712.c000.snappy.parquet
# Baixado: silver_data/country=sweden/part-00000-2bcf6258-f04e-41f3-9d79-8467e59fb83a.c000.snappy.parquet
# Baixado: silver_data/country=united states/part-00000-e295923a-7724-4b07-b651-0379be8f512b.c000.snappy.parquet
# Nenhum arquivo Parquet encontrado.
# Erro ao executar as consultas:
# Catalog Error: Table with name silver_data does not exist!
# Did you mean "pg_database"?
# LINE 1: SELECT COUNT(*) as total_records FROM silver_data;
#                                               ^
